# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from geopy.distance import geodesic
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import time
from IPython.display import clear_output

# %%
# Load the dataset
df = pd.read_csv('train.csv')

# Set the random seed
np.random.seed(8659)

# Sample 100,000 rows
df = df.sample(n=100000)

# %%
df.head()
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 209174   id2104500          2  2016-03-09 20:09:32  2016-03-09 20:33:18
# 1296156  id1063788          2  2016-05-26 08:38:50  2016-05-26 08:51:19
# 136770   id1376921          1  2016-06-12 10:36:15  2016-06-12 10:50:21
# 219673   id1418169          2  2016-06-26 02:13:21  2016-06-26 02:16:28
# 218117   id2470055          2  2016-02-17 11:33:38  2016-02-17 11:39:45
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 209174                 5            -74.00            40.74
# 1296156                1            -73.97            40.74
# 136770                 1            -73.99            40.73
# 219673                 1            -73.98            40.74
# 218117                 1            -73.98            40.73
#
#          dropoff_longitude  dropoff_latitude store_and_fwd_flag  trip_duration
# 209174              -73.96             40.67                  N           1426
# 1296156             -73.99             40.75                  N            749
# 136770              -74.00             40.71                  N            846
# 219673              -73.98             40.73                  N            187
# 218117              -73.99             40.73                  N            367

# %%
df.describe()
# Out:
#        vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  100000.00        100000.00         100000.00        100000.00
# mean        1.53             1.66            -73.97            40.75
# std         0.50             1.31              0.04             0.04
# min         1.00             0.00            -77.44            35.31
# 25%         1.00             1.00            -73.99            40.74
# 50%         2.00             1.00            -73.98            40.75
# 75%         2.00             2.00            -73.97            40.77
# max         2.00             6.00            -70.51            42.46
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count          100000.00         100000.00      100000.00
# mean              -73.97             40.75         942.74
# std                 0.04              0.04        3083.43
# min               -79.52             35.17           1.00
# 25%               -73.99             40.74         394.00
# 50%               -73.98             40.75         661.00
# 75%               -73.96             40.77        1073.00
# max               -70.51             43.92       86369.00

# %%
df.dtypes
# Out:
# id                     object
# vendor_id               int64
# pickup_datetime        object
# dropoff_datetime       object
# passenger_count         int64
# pickup_longitude      float64
# pickup_latitude       float64
# dropoff_longitude     float64
# dropoff_latitude      float64
# store_and_fwd_flag     object
# trip_duration           int64
# dtype: object

# %%
## Droping rows with nan values
df.dropna(inplace=True)

# %%
null_data = df.isnull().sum()
print("null data counts:")
print(null_data)
# Out:
# null data counts:
# id                    0
# vendor_id             0
# pickup_datetime       0
# dropoff_datetime      0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# trip_duration         0
# dtype: int64

# %%
df.head()
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 209174   id2104500          2  2016-03-09 20:09:32  2016-03-09 20:33:18
# 1296156  id1063788          2  2016-05-26 08:38:50  2016-05-26 08:51:19
# 136770   id1376921          1  2016-06-12 10:36:15  2016-06-12 10:50:21
# 219673   id1418169          2  2016-06-26 02:13:21  2016-06-26 02:16:28
# 218117   id2470055          2  2016-02-17 11:33:38  2016-02-17 11:39:45
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 209174                 5            -74.00            40.74
# 1296156                1            -73.97            40.74
# 136770                 1            -73.99            40.73
# 219673                 1            -73.98            40.74
# 218117                 1            -73.98            40.73
#
#          dropoff_longitude  dropoff_latitude store_and_fwd_flag  trip_duration
# 209174              -73.96             40.67                  N           1426
# 1296156             -73.99             40.75                  N            749
# 136770              -74.00             40.71                  N            846
# 219673              -73.98             40.73                  N            187
# 218117              -73.99             40.73                  N            367

# %%
df = df[df['trip_duration'] >= 0]

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
df['dropoff_datetime'] = pd.to_datetime(df['dropoff_datetime'])

# %%
df['month'] = df.pickup_datetime.dt.month

df['weekday'] = df['pickup_datetime'].dt.strftime('%A')

df['weekday_num'] = df.pickup_datetime.dt.weekday

df['pickup_hour'] = df.pickup_datetime.dt.hour

# %%
df.head()
# Out:
#                 id  vendor_id     pickup_datetime    dropoff_datetime  \
# 209174   id2104500          2 2016-03-09 20:09:32 2016-03-09 20:33:18
# 1296156  id1063788          2 2016-05-26 08:38:50 2016-05-26 08:51:19
# 136770   id1376921          1 2016-06-12 10:36:15 2016-06-12 10:50:21
# 219673   id1418169          2 2016-06-26 02:13:21 2016-06-26 02:16:28
# 218117   id2470055          2 2016-02-17 11:33:38 2016-02-17 11:39:45
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 209174                 5            -74.00            40.74
# 1296156                1            -73.97            40.74
# 136770                 1            -73.99            40.73
# 219673                 1            -73.98            40.74
# 218117                 1            -73.98            40.73
#
#          dropoff_longitude  dropoff_latitude store_and_fwd_flag  \
# 209174              -73.96             40.67                  N
# 1296156             -73.99             40.75                  N
# 136770              -74.00             40.71                  N
# 219673              -73.98             40.73                  N
# 218117              -73.99             40.73                  N
#
#          trip_duration  month    weekday  weekday_num  pickup_hour
# 209174            1426      3  Wednesday            2           20
# 1296156            749      5   Thursday            3            8
# 136770             846      6     Sunday            6           10
# 219673             187      6     Sunday            6            2
# 218117             367      2  Wednesday            2           11

# %%
df.dtypes
# Out:
# id                            object
# vendor_id                      int64
# pickup_datetime       datetime64[ns]
# dropoff_datetime      datetime64[ns]
# passenger_count                int64
# pickup_longitude             float64
# pickup_latitude              float64
# dropoff_longitude            float64
# dropoff_latitude             float64
# store_and_fwd_flag            object
# trip_duration                  int64
# month                          int32
# weekday                       object
# weekday_num                    int32
# pickup_hour                    int32
# dtype: object

# %%
df.value_counts()
# Out:
# id         vendor_id  pickup_datetime      dropoff_datetime     passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  store_and_fwd_flag  trip_duration  month  weekday   weekday_num  pickup_hour
# id0000063  2          2016-04-24 10:38:59  2016-04-24 10:46:34  1                -73.96            40.78            -73.98             40.77             N                   455            4      Sunday    6            10             1
# id2660312  2          2016-06-24 17:38:43  2016-06-24 18:07:03  1                -73.95            40.77            -73.99             40.74             N                   1700           6      Friday    4            17             1
# id2661341  1          2016-05-19 19:37:45  2016-05-19 19:59:57  1                -74.01            40.72            -74.01             40.72             N                   1332           5      Thursday  3            19             1
# id2661334  1          2016-02-14 03:54:20  2016-02-14 04:09:01  1                -73.99            40.76            -73.93             40.76             N                   881            2      Sunday    6            3              1
# id2661279  1          2016-03-03 22:22:14  2016-03-03 22:49:38  1                -73.87            40.77            -74.00             40.72             N                   1644           3      Thursday  3            22             1
#                                                                                                                                                                                                                                         ..
# id1333253  1          2016-02-13 11:50:07  2016-02-13 12:06:04  1                -74.00            40.76            -73.97             40.75             Y                   957            2      Saturday  5            11             1
# id1333117  1          2016-04-26 21:06:19  2016-04-26 21:30:12  1                -73.87            40.77            -74.01             40.72             N                   1433           4      Tuesday   1            21             1
# id1333107  1          2016-02-26 23:00:23  2016-02-26 23:20:27  1                -73.98            40.77            -74.02             40.70             N                   1204           2      Friday    4            23             1
# id1333076  2          2016-01-30 17:02:44  2016-01-30 17:17:05  1                -73.97            40.76            -73.98             40.78             N                   861            1      Saturday  5            17             1
# id3999962  2          2016-05-05 12:11:15  2016-05-05 12:14:19  1                -73.96            40.77            -73.95             40.78             N                   184            5      Thursday  3            12             1
# Name: count, Length: 100000, dtype: int64

# %%
# Creating dummy variables for store_and_fwd_flag within df2 and droping the first level
df = pd.get_dummies(df, columns=['store_and_fwd_flag'], drop_first=True)

# %%
# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot a bar chart in the first subplot
sns.countplot(data=df, x='vendor_id', ax=axes[0], palette='viridis')
axes[0].set_title('Vendors (Bar Chart)')
axes[0].set_xlabel('Vendor Id')
axes[0].set_ylabel('Count')

# Plot a pie chart in the second subplot
vendor_counts = df['vendor_id'].value_counts()
axes[1].pie(vendor_counts, labels=vendor_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('viridis'))
axes[1].set_title('Vendors (Pie Chart)')

# Adjust layout
fig.tight_layout()

# Show the plots
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Converting 'passenger_count' to integers and then count the values
df['passenger_count'] = df['passenger_count'].astype(int)
passenger_count_counts = df['passenger_count'].value_counts()

# Seting the display format to suppress scientific notation
pd.options.display.float_format = '{:.2f}'.format

# Display the value counts
print(passenger_count_counts)
# Out:
# passenger_count
# 1    70883
# 2    14403
# 5     5316
# 3     4096
# 6     3289
# 4     2006
# 0        7
# Name: count, dtype: int64

# %%
df = df[df['passenger_count'] > 0]

# %%
# Create a single figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 5))

# Bar plot for passenger count
sns.countplot(data=df, x='passenger_count', ax=axes[0])
axes[0].set_ylabel("Count", fontsize=15)
axes[0].set_xlabel("No. of Passengers", fontsize=15)
axes[0].set_title('Passenger Count (Bar Plot)', fontsize=20)

# Box plot for passenger count
sns.boxplot(data=df, x='passenger_count', orient='h', ax=axes[1])
axes[1].set_title('Passenger Count (Box Plot)', fontsize=20)

# Adjust layout
fig.tight_layout()

# Show the plots
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Replace 'df' with your actual DataFrame
plt.figure(figsize=(20, 5))
sns.boxplot(x=df['trip_duration'])
plt.title('Trip Duration Box Plot', fontsize=16)
plt.xlabel('Trip Duration', fontsize=14)
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
bin_edges = np.arange(0, df['trip_duration'].max(), 3600)

# Group and count trips based on trip duration bins
trip_counts = df['trip_duration'].groupby(pd.cut(df['trip_duration'], bin_edges)).count()

# Print the trip counts
print(trip_counts)
# Out:
# trip_duration
# (0, 3600]         99170
# (3600, 7200]        680
# (7200, 10800]         7
# (10800, 14400]        2
# (14400, 18000]        1
# (18000, 21600]        0
# (21600, 25200]        2
# (25200, 28800]        1
# (28800, 32400]        1
# (32400, 36000]        0
# (36000, 39600]        1
# (39600, 43200]        1
# (43200, 46800]        0
# (46800, 50400]        0
# (50400, 54000]        1
# (54000, 57600]        0
# (57600, 61200]        1
# (61200, 64800]        0
# (64800, 68400]        1
# (68400, 72000]        1
# (72000, 75600]        0
# (75600, 79200]        2
# (79200, 82800]        2
# Name: trip_duration, dtype: int64
# /var/folders/wz/dvpqqs715hs1594hzt3ncl540000gn/T/ipykernel_29680/3951350385.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   trip_counts = df['trip_duration'].groupby(pd.cut(df['trip_duration'], bin_edges)).count()

# %%
# Replace 'df' with your actual DataFrame
bin_labels = np.arange(1, 7200, 600)
trip_duration_counts = df['trip_duration'].groupby(pd.cut(df['trip_duration'], bin_labels)).count()

# Create a horizontal bar plot
plt.figure(figsize=(18, 5))
trip_duration_counts.plot(kind='barh')
plt.title('Trip Duration', fontsize=16)
plt.xlabel('Trip Counts', fontsize=14)
plt.ylabel('Trip Duration (seconds)', fontsize=14)
plt.show()
# Out:
# /var/folders/wz/dvpqqs715hs1594hzt3ncl540000gn/T/ipykernel_29680/254362850.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   trip_duration_counts = df['trip_duration'].groupby(pd.cut(df['trip_duration'], bin_labels)).count()

# %%
def clock(ax, radii, title, color):
    N = 24  # Number of hours in a day
    bottom = 2  # Bottom position for the bars

    # Create theta for 24 hours
    theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)

    # Width of each bin on the plot
    width = (2 * np.pi) / N

    # Create bars on the polar plot
    bars = ax.bar(theta, radii, width=width, bottom=bottom, color=color, edgecolor="#999999")

    # Set the label position to start from the top and go clockwise
    ax.set_theta_zero_location("N")  # "N" stands for North (top)
    ax.set_theta_direction(-1)  # Clockwise direction

    # Set the label ticks and format them as hours
    ax.set_xticks(theta)
    ticks = ["{}:00".format(x) for x in range(24)]
    ax.set_xticklabels(ticks)

    # Set the title of the polar plot
    ax.set_title(title)

# %%
plt.figure(figsize=(15, 15))
ax = plt.subplot(3, 3, 1, polar=True)

# Calculate the number of trips per hour and convert it to an array
radii = df['pickup_hour'].value_counts().sort_index().values

title = "Hourly trips"
clock(ax, radii, title, "#dc143c")

plt.show()

# %%
# Create a figure and axes
plt.figure(figsize=(19, 5))

# Create a countplot with custom month labels
ax = sns.countplot(data=df, x='month', palette='viridis')

# Set axis labels and title
ax.set_ylabel('Trip Counts', fontsize=15)
ax.set_xlabel('Months', fontsize=15)
ax.set_title('Trips per Month', fontsize=20)

# Specify the positions and labels for the x-axis ticks
month_positions = list(range(12))
month_labels = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Set the custom tick positions and labels for the x-axis
ax.set_xticks(month_positions)
ax.set_xticklabels(month_labels, rotation=45)

plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(12, 4))


group1 = df.groupby('pickup_hour')['trip_duration'].mean().reset_index()

# Create a point plot
point_plot = sns.pointplot(x='pickup_hour', y='trip_duration', data=group1, color='skyblue')

point_plot.set_ylabel('Trip Duration (seconds)', fontsize=10)
point_plot.set_xlabel('Pickup Hour', fontsize=10)
point_plot.set_title('Trip Duration per Hour', fontsize=15)

plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(12, 4))

# Group by weekday number and calculate the mean trip duration
group2 = df.groupby('weekday_num')['trip_duration'].mean().reset_index()

# Create a point plot
point_plot = sns.pointplot(x='weekday_num', y='trip_duration', data=group2, color='skyblue')

point_plot.set_ylabel('Trip Duration (seconds)', fontsize=10)
point_plot.set_xlabel('Weekday', fontsize=10)
point_plot.set_title('Trip Duration per Weekday', fontsize=15)

# Set x-axis labels to display the weekday names
weekday_labels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
point_plot.set_xticklabels(weekday_labels, rotation=45)

plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(12, 4))


group3 = df.groupby('month')['trip_duration'].mean().reset_index()

# Create a point plot
point_plot = sns.pointplot(x='month', y='trip_duration', data=group3, color='skyblue')

point_plot.set_ylabel('Trip Duration (seconds)', fontsize=10)
point_plot.set_xlabel('Month', fontsize=10)
point_plot.set_title('Trip Duration per Month', fontsize=15)

plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
group9 = df.groupby('vendor_id')['passenger_count'].mean().reset_index()

plt.figure(figsize=(12, 4))

# Create a bar plot
bar_plot = sns.barplot(x='vendor_id', y='passenger_count', data=group9, color='skyblue')

bar_plot.set_ylabel('Passenger Count', fontsize=10)
bar_plot.set_xlabel('Vendor ID', fontsize=10)
bar_plot.set_title('Passenger Count per Vendor', fontsize=15)

plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
group4 = df.groupby('vendor_id')['trip_duration'].mean().reset_index()

plt.figure(figsize=(12, 4))

# Create a bar plot
bar_plot = sns.barplot(x='vendor_id', y='trip_duration', data=group4, color='skyblue')

bar_plot.set_ylabel('Trip Duration (seconds)', fontsize=10)
bar_plot.set_xlabel('Vendor', fontsize=10)
bar_plot.set_title('Trip Duration per Vendor', fontsize=15)

plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(12, 4))

# Create a countplot with custom x-axis labels
count_plot = sns.countplot(data=df, x='weekday_num', palette='viridis')

count_plot.set_xlabel('Weekday', fontsize=15)
count_plot.set_ylabel('Trip Counts', fontsize=15)
count_plot.set_title('Trips per Day', fontsize=20)

# Set the x-axis labels to display weekdays
weekday_labels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
count_plot.set_xticklabels(weekday_labels, rotation=45)

plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Apply label encoding to the 'vendor_id' column and overwrite it
df['vendor_id'] = label_encoder.fit_transform(df['vendor_id'])

# %%
df.dtypes
# Out:
# id                              object
# vendor_id                        int64
# pickup_datetime         datetime64[ns]
# dropoff_datetime        datetime64[ns]
# passenger_count                  int64
# pickup_longitude               float64
# pickup_latitude                float64
# dropoff_longitude              float64
# dropoff_latitude               float64
# trip_duration                    int64
# month                            int32
# weekday                         object
# weekday_num                      int32
# pickup_hour                      int32
# store_and_fwd_flag_Y              bool
# dtype: object

# %%
df.head()
# Out:
#                 id  vendor_id     pickup_datetime    dropoff_datetime  \
# 209174   id2104500          1 2016-03-09 20:09:32 2016-03-09 20:33:18
# 1296156  id1063788          1 2016-05-26 08:38:50 2016-05-26 08:51:19
# 136770   id1376921          0 2016-06-12 10:36:15 2016-06-12 10:50:21
# 219673   id1418169          1 2016-06-26 02:13:21 2016-06-26 02:16:28
# 218117   id2470055          1 2016-02-17 11:33:38 2016-02-17 11:39:45
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 209174                 5            -74.00            40.74
# 1296156                1            -73.97            40.74
# 136770                 1            -73.99            40.73
# 219673                 1            -73.98            40.74
# 218117                 1            -73.98            40.73
#
#          dropoff_longitude  dropoff_latitude  trip_duration  month    weekday  \
# 209174              -73.96             40.67           1426      3  Wednesday
# 1296156             -73.99             40.75            749      5   Thursday
# 136770              -74.00             40.71            846      6     Sunday
# 219673              -73.98             40.73            187      6     Sunday
# 218117              -73.99             40.73            367      2  Wednesday
#
#          weekday_num  pickup_hour  store_and_fwd_flag_Y
# 209174             2           20                 False
# 1296156            3            8                 False
# 136770             6           10                 False
# 219673             6            2                 False
# 218117             2           11                 False

# %%
from sklearn.preprocessing import MinMaxScaler


scaler = MinMaxScaler()
normalizing_column = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']
df[normalizing_column] = scaler.fit_transform(df[normalizing_column])

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler object
scaler = StandardScaler()

# Define the columns to be standardized
columns_to_standardize = ['trip_duration']

# Apply standardization to the selected columns
df[columns_to_standardize] = scaler.fit_transform(df[columns_to_standardize])

# %%
from scipy import stats

# Select the numerical columns for outlier detection
numerical_columns = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'trip_duration']

# Calculate the absolute Z-scores for each numerical column
z_scores = np.abs(stats.zscore(df[numerical_columns]))

# Define a threshold for considering data points as outliers (adjust as needed)
z_threshold = 3.0

# Find rows with outliers
outliers = (z_scores > z_threshold).any(axis=1)

# Remove rows with outliers
df_clean = df[~outliers]

# Display the cleaned DataFrame
df_clean.head()

df = df_clean

# Display the cleaned DataFrame
df.head()
# Out:
#                 id  vendor_id     pickup_datetime    dropoff_datetime  \
# 209174   id2104500          1 2016-03-09 20:09:32 2016-03-09 20:33:18
# 1296156  id1063788          1 2016-05-26 08:38:50 2016-05-26 08:51:19
# 136770   id1376921          0 2016-06-12 10:36:15 2016-06-12 10:50:21
# 219673   id1418169          1 2016-06-26 02:13:21 2016-06-26 02:16:28
# 218117   id2470055          1 2016-02-17 11:33:38 2016-02-17 11:39:45
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 209174                 5              0.50             0.76
# 1296156                1              0.50             0.76
# 136770                 1              0.50             0.76
# 219673                 1              0.50             0.76
# 218117                 1              0.50             0.76
#
#          dropoff_longitude  dropoff_latitude  trip_duration  month    weekday  \
# 209174                0.62              0.63           0.16      3  Wednesday
# 1296156               0.61              0.64          -0.06      5   Thursday
# 136770                0.61              0.63          -0.03      6     Sunday
# 219673                0.62              0.64          -0.25      6     Sunday
# 218117                0.61              0.64          -0.19      2  Wednesday
#
#          weekday_num  pickup_hour  store_and_fwd_flag_Y
# 209174             2           20                 False
# 1296156            3            8                 False
# 136770             6           10                 False
# 219673             6            2                 False
# 218117             2           11                 False

# %%
df.shape
# Out:
# (95944, 15)

# %%
# Select only the numeric columns in your DataFrame
df2_matrix_columns = df.select_dtypes(include=['number'])
df2_matrix = df2_matrix_columns.corr()

# Creating a heatmap with a different color palette ('viridis' in this case)
plt.figure(figsize=(10, 8))
sns.heatmap(df2_matrix, annot=True, cmap='viridis', linewidths=0.7)
plt.title('Heatmap')
plt.show()

# %%
X = df[predictors]
#y = df[target]
y = df.iloc[:,9].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7294)

# %%
from sklearn.decomposition import PCA

# Fit PCA to your training data
pca = PCA()
pca.fit(X_train)

# Calculate the cumulative explained variance
cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)

# Create a plot to visualize the cumulative explained variance
plt.figure(figsize=(8, 6))
plt.plot(cumulative_explained_variance, marker='o')
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Cumulative Explained Variance by Principal Components")
plt.grid()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import  r2_score



predictors = ['vendor_id', 'passenger_count', 'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'month', 'weekday_num', 'pickup_hour']
target = 'trip_duration'


X = df[predictors]
y = df.iloc[:,9].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7294)


#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state = 7294)

# Creating a linear regression model
model = LinearRegression()


model.fit(X_train, y_train)


y_pred = model.predict(X_test)


r_2 = r2_score(y_test, y_pred)


coefficients = dict(zip(predictors, model.coef_))
print(" Coefficients:")
print(coefficients)


print("R-squared (R2) Score:", r_2)
# Out:
#  Coefficients:
# {'vendor_id': 0.00028161305479379136, 'passenger_count': 0.001164609792537471, 'pickup_longitude': 9.079860980494589, 'pickup_latitude': -4.991914243624176, 'dropoff_longitude': 13.884727506394912, 'dropoff_latitude': -10.578187813047725, 'month': 0.006634290847880708, 'weekday_num': -0.003508613867312073, 'pickup_hour': 0.00122439632712068}
# R-squared (R2) Score: 0.09122909659551959

# %%
cumulative_variance = np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4) * 100)
explained_variance = list(zip(range(1, len(cumulative_variance) + 1), cumulative_variance))
print(explained_variance)
# Out:
# [(1, 82.78), (2, 90.34), (3, 96.02000000000001), (4, 99.55000000000001), (5, 100.00000000000001), (6, 100.00000000000001), (7, 100.00000000000001), (8, 100.00000000000001), (9, 100.00000000000001)]

# %%
from sklearn.tree import DecisionTreeRegressor

# Create and fit the Decision Tree regression model, measuring the time
start_time = time.time()
dt_regression = DecisionTreeRegressor().fit(X_train, y_train)
end_time = time.time()
dt_time = end_time - start_time

print(f"Time to train Decision Tree model: {dt_time:.2f} seconds")

# Predict on the test data
trips = dt_regression.predict(X_test)
# Out:
# Time to train Decision Tree model: 0.75 seconds

# %%
de_t_score = r2_score(y_test, trips)
print(de_t_score)
# Out:
# 0.37492019030101775

# %%
from sortedcontainers import SortedDict
sorted_trip_data = SortedDict()
for index, row in df.iterrows():
    tr_id = row['id']
    trip_duration = row['trip_duration']
    sorted_trip_data[trip_duration] = (tr_id, row)
new_trp_id = 'new_trp_id'
new_tr_duration = 500
new_tr_data = {
    'vendor_id': 'new_vendor',
    'pickup_datetime': '2023-10-28 10:00:00',
    'dropoff_datetime': '2023-10-28 10:30:00',
    'passenger_count': 3,
    'pickup_longitude': -73.9895,
    'pickup_latitude': 40.7523,
    'dropoff_longitude': -73.9876,
    'dropoff_latitude': 40.7612,
    'store_and_fwd_flag': 'N',
}
sorted_trip_data[new_tr_duration] = (new_trp_id, new_tr_data)
for duration, (tr_id, data) in sorted_trip_data.items():
    print(f"Trip ID: {tr_id}, Duration: {duration} seconds")
# Out:
# Trip ID: id3712815, Duration: -0.30631918542086234 seconds
# Trip ID: id0771057, Duration: -0.3059936421418518 seconds
# Trip ID: id2899379, Duration: -0.3056680988628413 seconds
# Trip ID: id3499191, Duration: -0.3053425555838308 seconds
# Trip ID: id0048237, Duration: -0.30501701230482026 seconds
# Trip ID: id2621196, Duration: -0.30469146902580974 seconds
# Trip ID: id1840822, Duration: -0.3043659257467992 seconds
# Trip ID: id2589768, Duration: -0.30404038246778875 seconds
# Trip ID: id2841671, Duration: -0.30371483918877823 seconds
# Trip ID: id1550403, Duration: -0.3033892959097677 seconds
# Trip ID: id2431464, Duration: -0.3030637526307572 seconds
# Trip ID: id0842166, Duration: -0.30273820935174667 seconds
# Trip ID: id0430308, Duration: -0.30241266607273615 seconds
# Trip ID: id1021500, Duration: -0.3020871227937256 seconds
# Trip ID: id0761104, Duration: -0.3017615795147151 seconds
# Trip ID: id0925860, Duration: -0.3014360362357046 seconds
# Trip ID: id1839162, Duration: -0.30111049295669406 seconds
# Trip ID: id0512802, Duration: -0.3007849496776836 seconds
# Trip ID: id2864109, Duration: -0.3004594063986731 seconds
# Trip ID: id3433450, Duration: -0.30013386311966256 seconds
# Trip ID: id1487168, Duration: -0.29980831984065204 seconds
# Trip ID: id0889412, Duration: -0.2994827765616415 seconds
# Trip ID: id1729290, Duration: -0.299157233282631 seconds
# Trip ID: id2284694, Duration: -0.2988316900036205 seconds
# Trip ID: id3294655, Duration: -0.29850614672460996 seconds
# Trip ID: id2389225, Duration: -0.29818060344559943 seconds
# Trip ID: id2589593, Duration: -0.2978550601665889 seconds
# Trip ID: id3439215, Duration: -0.29752951688757845 seconds
# Trip ID: id1201391, Duration: -0.29720397360856793 seconds
# Trip ID: id3763183, Duration: -0.2968784303295574 seconds
# Trip ID: id1682759, Duration: -0.2965528870505469 seconds
# Trip ID: id3249388, Duration: -0.29622734377153637 seconds
# Trip ID: id1496106, Duration: -0.29590180049252585 seconds
# Trip ID: id2198833, Duration: -0.2955762572135153 seconds
# Trip ID: id1231366, Duration: -0.2952507139345048 seconds
# Trip ID: id1995419, Duration: -0.2949251706554943 seconds
# Trip ID: id0942822, Duration: -0.29459962737648376 seconds
# Trip ID: id3022106, Duration: -0.2942740840974733 seconds
# Trip ID: id3277486, Duration: -0.2939485408184628 seconds
# Trip ID: id1875536, Duration: -0.29362299753945226 seconds
# Trip ID: id1226905, Duration: -0.29329745426044174 seconds
# Trip ID: id0550504, Duration: -0.2929719109814312 seconds
# Trip ID: id3571452, Duration: -0.2926463677024207 seconds
# Trip ID: id2588161, Duration: -0.2923208244234102 seconds
# Trip ID: id1710285, Duration: -0.29199528114439965 seconds
# Trip ID: id3512256, Duration: -0.29166973786538913 seconds
# Trip ID: id0885588, Duration: -0.2913441945863786 seconds
# Trip ID: id0731243, Duration: -0.29101865130736815 seconds
# Trip ID: id2131375, Duration: -0.2906931080283576 seconds
# Trip ID: id3459994, Duration: -0.2903675647493471 seconds
# Trip ID: id2988432, Duration: -0.2900420214703366 seconds
# Trip ID: id3499840, Duration: -0.28971647819132607 seconds
# Trip ID: id1971948, Duration: -0.28939093491231555 seconds
# Trip ID: id2051469, Duration: -0.289065391633305 seconds
# Trip ID: id0519099, Duration: -0.2887398483542945 seconds
# Trip ID: id3104176, Duration: -0.288414305075284 seconds
# Trip ID: id2865766, Duration: -0.28808876179627346 seconds
# Trip ID: id3899530, Duration: -0.287763218517263 seconds
# Trip ID: id0430311, Duration: -0.2874376752382525 seconds
# Trip ID: id3339993, Duration: -0.28711213195924196 seconds
# Trip ID: id0612887, Duration: -0.28678658868023144 seconds
# Trip ID: id2006686, Duration: -0.2864610454012209 seconds
# Trip ID: id0766518, Duration: -0.2861355021222104 seconds
# Trip ID: id2005544, Duration: -0.2858099588431999 seconds
# Trip ID: id1756449, Duration: -0.28548441556418935 seconds
# Trip ID: id3657837, Duration: -0.28515887228517883 seconds
# Trip ID: id0581706, Duration: -0.2848333290061683 seconds
# Trip ID: id2907046, Duration: -0.28450778572715785 seconds
# Trip ID: id3458751, Duration: -0.2841822424481473 seconds
# Trip ID: id3296274, Duration: -0.2838566991691368 seconds
# Trip ID: id1466700, Duration: -0.2835311558901263 seconds
# Trip ID: id3141807, Duration: -0.28320561261111576 seconds
# Trip ID: id1448826, Duration: -0.28288006933210524 seconds
# Trip ID: id2457696, Duration: -0.2825545260530947 seconds
# Trip ID: id3778956, Duration: -0.2822289827740842 seconds
# Trip ID: id1873024, Duration: -0.2819034394950737 seconds
# Trip ID: id2408063, Duration: -0.28157789621606316 seconds
# Trip ID: id1174062, Duration: -0.2812523529370527 seconds
# Trip ID: id1411640, Duration: -0.2809268096580422 seconds
# Trip ID: id2503616, Duration: -0.28060126637903166 seconds
# Trip ID: id3919091, Duration: -0.28027572310002113 seconds
# Trip ID: id1761047, Duration: -0.2799501798210106 seconds
# Trip ID: id1682766, Duration: -0.2796246365420001 seconds
# Trip ID: id0947917, Duration: -0.2792990932629896 seconds
# Trip ID: id3058210, Duration: -0.27897354998397905 seconds
# Trip ID: id3983462, Duration: -0.27864800670496853 seconds
# Trip ID: id1881190, Duration: -0.278322463425958 seconds
# Trip ID: id0544638, Duration: -0.27799692014694755 seconds
# Trip ID: id3949077, Duration: -0.277671376867937 seconds
# Trip ID: id0329601, Duration: -0.2773458335889265 seconds
# Trip ID: id0110344, Duration: -0.277020290309916 seconds
# Trip ID: id1236861, Duration: -0.27669474703090546 seconds
# Trip ID: id0276337, Duration: -0.27636920375189494 seconds
# Trip ID: id1909425, Duration: -0.2760436604728844 seconds
# Trip ID: id3702692, Duration: -0.2757181171938739 seconds
# Trip ID: id2858984, Duration: -0.2753925739148634 seconds
# Trip ID: id0008737, Duration: -0.27506703063585286 seconds
# Trip ID: id1876345, Duration: -0.2747414873568424 seconds
# Trip ID: id2690950, Duration: -0.2744159440778319 seconds
# Trip ID: id0317696, Duration: -0.27409040079882135 seconds
# Trip ID: id1948062, Duration: -0.27376485751981083 seconds
# Trip ID: id0036769, Duration: -0.2734393142408003 seconds
# Trip ID: id1484181, Duration: -0.2731137709617898 seconds
# Trip ID: id0096141, Duration: -0.27278822768277927 seconds
# Trip ID: id1890048, Duration: -0.27246268440376875 seconds
# Trip ID: id3781243, Duration: -0.27213714112475823 seconds
# Trip ID: id0759553, Duration: -0.2718115978457477 seconds
# Trip ID: id0590352, Duration: -0.27148605456673724 seconds
# Trip ID: id0082758, Duration: -0.2711605112877267 seconds
# Trip ID: id1655796, Duration: -0.2708349680087162 seconds
# Trip ID: id0295565, Duration: -0.2705094247297057 seconds
# Trip ID: id1222484, Duration: -0.27018388145069516 seconds
# Trip ID: id1166285, Duration: -0.26985833817168464 seconds
# Trip ID: id0173876, Duration: -0.2695327948926741 seconds
# Trip ID: id1294612, Duration: -0.2692072516136636 seconds
# Trip ID: id3786382, Duration: -0.2688817083346531 seconds
# Trip ID: id0731139, Duration: -0.26855616505564256 seconds
# Trip ID: id0892214, Duration: -0.26823062177663204 seconds
# Trip ID: id2568022, Duration: -0.2679050784976216 seconds
# Trip ID: id2630877, Duration: -0.26757953521861105 seconds
# Trip ID: id3031716, Duration: -0.26725399193960053 seconds
# Trip ID: id1089003, Duration: -0.26692844866059 seconds
# Trip ID: id3367720, Duration: -0.2666029053815795 seconds
# Trip ID: id0885861, Duration: -0.26627736210256897 seconds
# Trip ID: id2642452, Duration: -0.26595181882355845 seconds
# Trip ID: id3692930, Duration: -0.26562627554454793 seconds
# Trip ID: id1695206, Duration: -0.2653007322655374 seconds
# Trip ID: id3134275, Duration: -0.2649751889865269 seconds
# Trip ID: id3967326, Duration: -0.2646496457075164 seconds
# Trip ID: id0307333, Duration: -0.2643241024285059 seconds
# Trip ID: id2744376, Duration: -0.2639985591494954 seconds
# Trip ID: id2446929, Duration: -0.26367301587048486 seconds
# Trip ID: id3787160, Duration: -0.26334747259147434 seconds
# Trip ID: id3316342, Duration: -0.2630219293124638 seconds
# Trip ID: id2394607, Duration: -0.2626963860334533 seconds
# Trip ID: id0695455, Duration: -0.2623708427544428 seconds
# Trip ID: id2149003, Duration: -0.26204529947543226 seconds
# Trip ID: id0320253, Duration: -0.26171975619642174 seconds
# Trip ID: id3890179, Duration: -0.2613942129174113 seconds
# Trip ID: id1020747, Duration: -0.26106866963840075 seconds
# Trip ID: id0617800, Duration: -0.26074312635939023 seconds
# Trip ID: id0201719, Duration: -0.2604175830803797 seconds
# Trip ID: id2018481, Duration: -0.2600920398013692 seconds
# Trip ID: id3218072, Duration: -0.25976649652235867 seconds
# Trip ID: id0944802, Duration: -0.25944095324334815 seconds
# Trip ID: id1233638, Duration: -0.25911540996433763 seconds
# Trip ID: id3978530, Duration: -0.2587898666853271 seconds
# Trip ID: id1098545, Duration: -0.2584643234063166 seconds
# Trip ID: id0373546, Duration: -0.2581387801273061 seconds
# Trip ID: id1951099, Duration: -0.2578132368482956 seconds
# Trip ID: id1668381, Duration: -0.2574876935692851 seconds
# Trip ID: id0889964, Duration: -0.25716215029027456 seconds
# Trip ID: id2207798, Duration: -0.25683660701126404 seconds
# Trip ID: id0155956, Duration: -0.2565110637322535 seconds
# Trip ID: id0575217, Duration: -0.256185520453243 seconds
# Trip ID: id2942382, Duration: -0.2558599771742325 seconds
# Trip ID: id2492046, Duration: -0.25553443389522196 seconds
# Trip ID: id3771784, Duration: -0.25520889061621144 seconds
# Trip ID: id3268591, Duration: -0.25488334733720097 seconds
# Trip ID: id2626416, Duration: -0.25455780405819045 seconds
# Trip ID: id0244442, Duration: -0.25423226077917993 seconds
# Trip ID: id0735793, Duration: -0.2539067175001694 seconds
# Trip ID: id0357970, Duration: -0.2535811742211589 seconds
# Trip ID: id2807471, Duration: -0.25325563094214837 seconds
# Trip ID: id3724027, Duration: -0.25293008766313785 seconds
# Trip ID: id3882827, Duration: -0.2526045443841273 seconds
# Trip ID: id1146373, Duration: -0.2522790011051168 seconds
# Trip ID: id2517716, Duration: -0.2519534578261063 seconds
# Trip ID: id0494179, Duration: -0.2516279145470958 seconds
# Trip ID: id0714857, Duration: -0.2513023712680853 seconds
# Trip ID: id2639425, Duration: -0.2509768279890748 seconds
# Trip ID: id2723976, Duration: -0.25065128471006426 seconds
# Trip ID: id2449354, Duration: -0.25032574143105374 seconds
# Trip ID: id3576355, Duration: -0.2500001981520432 seconds
# Trip ID: id3100259, Duration: -0.2496746548730327 seconds
# Trip ID: id2190288, Duration: -0.2493491115940222 seconds
# Trip ID: id3095880, Duration: -0.24902356831501168 seconds
# Trip ID: id3720452, Duration: -0.24869802503600116 seconds
# Trip ID: id3802617, Duration: -0.24837248175699064 seconds
# Trip ID: id3033743, Duration: -0.24804693847798012 seconds
# Trip ID: id2097531, Duration: -0.24772139519896963 seconds
# Trip ID: id1407501, Duration: -0.2473958519199591 seconds
# Trip ID: id0682147, Duration: -0.2470703086409486 seconds
# Trip ID: id2507147, Duration: -0.24674476536193807 seconds
# Trip ID: id3176092, Duration: -0.24641922208292755 seconds
# Trip ID: id1172182, Duration: -0.24609367880391703 seconds
# Trip ID: id0396259, Duration: -0.24576813552490653 seconds
# Trip ID: id1300707, Duration: -0.245442592245896 seconds
# Trip ID: id1466568, Duration: -0.2451170489668855 seconds
# Trip ID: id0939295, Duration: -0.24479150568787497 seconds
# Trip ID: id0349674, Duration: -0.24446596240886445 seconds
# Trip ID: id0066078, Duration: -0.24414041912985396 seconds
# Trip ID: id2009649, Duration: -0.24381487585084344 seconds
# Trip ID: id3192816, Duration: -0.24348933257183292 seconds
# Trip ID: id0749369, Duration: -0.2431637892928224 seconds
# Trip ID: id1043479, Duration: -0.24283824601381188 seconds
# Trip ID: id0403819, Duration: -0.24251270273480138 seconds
# Trip ID: id1549931, Duration: -0.24218715945579086 seconds
# Trip ID: id0088684, Duration: -0.24186161617678034 seconds
# Trip ID: id3171305, Duration: -0.24153607289776982 seconds
# Trip ID: id1525822, Duration: -0.2412105296187593 seconds
# Trip ID: id0530064, Duration: -0.2408849863397488 seconds
# Trip ID: id2762849, Duration: -0.2405594430607383 seconds
# Trip ID: id1336664, Duration: -0.24023389978172777 seconds
# Trip ID: id2603391, Duration: -0.23990835650271725 seconds
# Trip ID: id1110291, Duration: -0.23958281322370673 seconds
# Trip ID: id2719878, Duration: -0.23925726994469623 seconds
# Trip ID: id0698162, Duration: -0.2389317266656857 seconds
# Trip ID: id2979098, Duration: -0.2386061833866752 seconds
# Trip ID: id1146789, Duration: -0.23828064010766467 seconds
# Trip ID: id0245116, Duration: -0.23795509682865415 seconds
# Trip ID: id3225108, Duration: -0.23762955354964366 seconds
# Trip ID: id3210264, Duration: -0.23730401027063314 seconds
# Trip ID: id2269800, Duration: -0.23697846699162262 seconds
# Trip ID: id2272209, Duration: -0.2366529237126121 seconds
# Trip ID: id2994399, Duration: -0.23632738043360157 seconds
# Trip ID: id0444393, Duration: -0.23600183715459108 seconds
# Trip ID: id2699582, Duration: -0.23567629387558056 seconds
# Trip ID: id3977716, Duration: -0.23535075059657004 seconds
# Trip ID: id1178275, Duration: -0.23502520731755952 seconds
# Trip ID: id3610550, Duration: -0.234699664038549 seconds
# Trip ID: id3305299, Duration: -0.2343741207595385 seconds
# Trip ID: id1263247, Duration: -0.234048577480528 seconds
# Trip ID: id0846816, Duration: -0.23372303420151747 seconds
# Trip ID: id0567637, Duration: -0.23339749092250694 seconds
# Trip ID: id0044822, Duration: -0.23307194764349642 seconds
# Trip ID: id3928825, Duration: -0.23274640436448593 seconds
# Trip ID: id0403114, Duration: -0.2324208610854754 seconds
# Trip ID: id2716100, Duration: -0.2320953178064649 seconds
# Trip ID: id3501291, Duration: -0.23176977452745437 seconds
# Trip ID: id2270940, Duration: -0.23144423124844385 seconds
# Trip ID: id3134223, Duration: -0.23111868796943336 seconds
# Trip ID: id1333651, Duration: -0.23079314469042284 seconds
# Trip ID: id2872264, Duration: -0.23046760141141232 seconds
# Trip ID: id1216488, Duration: -0.2301420581324018 seconds
# Trip ID: id2946918, Duration: -0.22981651485339127 seconds
# Trip ID: id1549394, Duration: -0.22949097157438078 seconds
# Trip ID: id3705940, Duration: -0.22916542829537026 seconds
# Trip ID: id1006837, Duration: -0.22883988501635974 seconds
# Trip ID: id1486697, Duration: -0.22851434173734922 seconds
# Trip ID: id0810740, Duration: -0.2281887984583387 seconds
# Trip ID: id3724503, Duration: -0.2278632551793282 seconds
# Trip ID: id2440910, Duration: -0.22753771190031769 seconds
# Trip ID: id1261486, Duration: -0.22721216862130716 seconds
# Trip ID: id0365372, Duration: -0.22688662534229664 seconds
# Trip ID: id3345463, Duration: -0.22656108206328612 seconds
# Trip ID: id0320852, Duration: -0.22623553878427563 seconds
# Trip ID: id2611721, Duration: -0.2259099955052651 seconds
# Trip ID: id2310640, Duration: -0.2255844522262546 seconds
# Trip ID: id0854155, Duration: -0.22525890894724407 seconds
# Trip ID: id1445119, Duration: -0.22493336566823355 seconds
# Trip ID: id2303351, Duration: -0.22460782238922306 seconds
# Trip ID: id3062450, Duration: -0.22428227911021253 seconds
# Trip ID: id0870005, Duration: -0.22395673583120201 seconds
# Trip ID: id1492939, Duration: -0.2236311925521915 seconds
# Trip ID: id3718753, Duration: -0.22330564927318097 seconds
# Trip ID: id1144257, Duration: -0.22298010599417048 seconds
# Trip ID: id0251370, Duration: -0.22265456271515996 seconds
# Trip ID: id3796778, Duration: -0.22232901943614944 seconds
# Trip ID: id0277680, Duration: -0.22200347615713892 seconds
# Trip ID: id1624027, Duration: -0.2216779328781284 seconds
# Trip ID: id0485057, Duration: -0.2213523895991179 seconds
# Trip ID: id2071604, Duration: -0.22102684632010738 seconds
# Trip ID: id2345989, Duration: -0.22070130304109686 seconds
# Trip ID: id3748874, Duration: -0.22037575976208634 seconds
# Trip ID: id1832107, Duration: -0.22005021648307582 seconds
# Trip ID: id1800605, Duration: -0.21972467320406533 seconds
# Trip ID: id2033146, Duration: -0.2193991299250548 seconds
# Trip ID: id2300650, Duration: -0.2190735866460443 seconds
# Trip ID: id3361183, Duration: -0.21874804336703377 seconds
# Trip ID: id3320304, Duration: -0.21842250008802325 seconds
# Trip ID: id1703434, Duration: -0.21809695680901275 seconds
# Trip ID: id1879771, Duration: -0.21777141353000223 seconds
# Trip ID: id2801767, Duration: -0.2174458702509917 seconds
# Trip ID: id1887057, Duration: -0.2171203269719812 seconds
# Trip ID: id2987699, Duration: -0.21679478369297067 seconds
# Trip ID: id1967507, Duration: -0.21646924041396018 seconds
# Trip ID: id0384465, Duration: -0.21614369713494966 seconds
# Trip ID: id1421828, Duration: -0.21581815385593914 seconds
# Trip ID: id0545612, Duration: -0.21549261057692862 seconds
# Trip ID: id3821633, Duration: -0.2151670672979181 seconds
# Trip ID: id2433226, Duration: -0.2148415240189076 seconds
# Trip ID: id2858139, Duration: -0.21451598073989708 seconds
# Trip ID: id3273871, Duration: -0.21419043746088656 seconds
# Trip ID: id0903964, Duration: -0.21386489418187604 seconds
# Trip ID: id2585549, Duration: -0.21353935090286552 seconds
# Trip ID: id2822735, Duration: -0.21321380762385503 seconds
# Trip ID: id0486364, Duration: -0.2128882643448445 seconds
# Trip ID: id1651560, Duration: -0.212562721065834 seconds
# Trip ID: id2106336, Duration: -0.21223717778682347 seconds
# Trip ID: id0080770, Duration: -0.21191163450781295 seconds
# Trip ID: id0640759, Duration: -0.21158609122880245 seconds
# Trip ID: id1601569, Duration: -0.21126054794979193 seconds
# Trip ID: id3641465, Duration: -0.2109350046707814 seconds
# Trip ID: id0514868, Duration: -0.2106094613917709 seconds
# Trip ID: id1063960, Duration: -0.21028391811276037 seconds
# Trip ID: id3746883, Duration: -0.20995837483374988 seconds
# Trip ID: id0490188, Duration: -0.20963283155473936 seconds
# Trip ID: id1543619, Duration: -0.20930728827572884 seconds
# Trip ID: id2103681, Duration: -0.20898174499671832 seconds
# Trip ID: id3496746, Duration: -0.2086562017177078 seconds
# Trip ID: id1261185, Duration: -0.2083306584386973 seconds
# Trip ID: id3947610, Duration: -0.20800511515968678 seconds
# Trip ID: id1583434, Duration: -0.20767957188067626 seconds
# Trip ID: id1652660, Duration: -0.20735402860166574 seconds
# Trip ID: id2329988, Duration: -0.20702848532265522 seconds
# Trip ID: id0451365, Duration: -0.20670294204364473 seconds
# Trip ID: id1555789, Duration: -0.2063773987646342 seconds
# Trip ID: id0249011, Duration: -0.2060518554856237 seconds
# Trip ID: id1142424, Duration: -0.20572631220661317 seconds
# Trip ID: id0037440, Duration: -0.20540076892760264 seconds
# Trip ID: id1794461, Duration: -0.20507522564859215 seconds
# Trip ID: id0549234, Duration: -0.20474968236958163 seconds
# Trip ID: id2232752, Duration: -0.2044241390905711 seconds
# Trip ID: id0726362, Duration: -0.2040985958115606 seconds
# Trip ID: id3428610, Duration: -0.20377305253255007 seconds
# Trip ID: id0502487, Duration: -0.20344750925353955 seconds
# Trip ID: id1434065, Duration: -0.20312196597452906 seconds
# Trip ID: id3177660, Duration: -0.20279642269551854 seconds
# Trip ID: id1446505, Duration: -0.20247087941650802 seconds
# Trip ID: id0670792, Duration: -0.2021453361374975 seconds
# Trip ID: id2457269, Duration: -0.20181979285848697 seconds
# Trip ID: id1088524, Duration: -0.20149424957947648 seconds
# Trip ID: id3294751, Duration: -0.20116870630046596 seconds
# Trip ID: id3536488, Duration: -0.20084316302145544 seconds
# Trip ID: id0254088, Duration: -0.20051761974244492 seconds
# Trip ID: id2555356, Duration: -0.2001920764634344 seconds
# Trip ID: id1451925, Duration: -0.1998665331844239 seconds
# Trip ID: id1528179, Duration: -0.19954098990541339 seconds
# Trip ID: id0131956, Duration: -0.19921544662640286 seconds
# Trip ID: id0186285, Duration: -0.19888990334739234 seconds
# Trip ID: id1949975, Duration: -0.19856436006838182 seconds
# Trip ID: id3568608, Duration: -0.19823881678937133 seconds
# Trip ID: id2109331, Duration: -0.1979132735103608 seconds
# Trip ID: id2435665, Duration: -0.1975877302313503 seconds
# Trip ID: id3078368, Duration: -0.19726218695233977 seconds
# Trip ID: id3464339, Duration: -0.19693664367332925 seconds
# Trip ID: id0483633, Duration: -0.19661110039431876 seconds
# Trip ID: id1041089, Duration: -0.19628555711530823 seconds
# Trip ID: id2102114, Duration: -0.19596001383629771 seconds
# Trip ID: id0133290, Duration: -0.1956344705572872 seconds
# Trip ID: id0104178, Duration: -0.19530892727827667 seconds
# Trip ID: id1214544, Duration: -0.19498338399926618 seconds
# Trip ID: id3559433, Duration: -0.19465784072025566 seconds
# Trip ID: id0728479, Duration: -0.19433229744124514 seconds
# Trip ID: id1159008, Duration: -0.19400675416223462 seconds
# Trip ID: id2870813, Duration: -0.1936812108832241 seconds
# Trip ID: id2616377, Duration: -0.1933556676042136 seconds
# Trip ID: id3046093, Duration: -0.19303012432520308 seconds
# Trip ID: id1304624, Duration: -0.19270458104619256 seconds
# Trip ID: id2423839, Duration: -0.19237903776718204 seconds
# Trip ID: id3516357, Duration: -0.19205349448817152 seconds
# Trip ID: id0985464, Duration: -0.19172795120916103 seconds
# Trip ID: id1148031, Duration: -0.1914024079301505 seconds
# Trip ID: id2093906, Duration: -0.19107686465114 seconds
# Trip ID: id3202031, Duration: -0.19075132137212947 seconds
# Trip ID: id0081754, Duration: -0.19042577809311895 seconds
# Trip ID: id0254938, Duration: -0.19010023481410845 seconds
# Trip ID: id2051903, Duration: -0.18977469153509793 seconds
# Trip ID: id3247953, Duration: -0.1894491482560874 seconds
# Trip ID: id3262947, Duration: -0.1891236049770769 seconds
# Trip ID: id2195934, Duration: -0.18879806169806637 seconds
# Trip ID: id0586574, Duration: -0.18847251841905588 seconds
# Trip ID: id0652962, Duration: -0.18814697514004536 seconds
# Trip ID: id0045796, Duration: -0.18782143186103484 seconds
# Trip ID: id1603791, Duration: -0.18749588858202432 seconds
# Trip ID: id1906727, Duration: -0.1871703453030138 seconds
# Trip ID: id3508621, Duration: -0.1868448020240033 seconds
# Trip ID: id0946347, Duration: -0.18651925874499278 seconds
# Trip ID: id2506650, Duration: -0.18619371546598226 seconds
# Trip ID: id3549871, Duration: -0.18586817218697174 seconds
# Trip ID: id3969448, Duration: -0.18554262890796122 seconds
# Trip ID: id1021469, Duration: -0.18521708562895073 seconds
# Trip ID: id0463825, Duration: -0.1848915423499402 seconds
# Trip ID: id1774903, Duration: -0.1845659990709297 seconds
# Trip ID: id1271947, Duration: -0.18424045579191917 seconds
# Trip ID: id1740097, Duration: -0.18391491251290865 seconds
# Trip ID: id1645806, Duration: -0.18358936923389815 seconds
# Trip ID: id0859053, Duration: -0.18326382595488763 seconds
# Trip ID: id0457690, Duration: -0.1829382826758771 seconds
# Trip ID: id3818919, Duration: -0.1826127393968666 seconds
# Trip ID: id2445292, Duration: -0.18228719611785607 seconds
# Trip ID: id2817195, Duration: -0.18196165283884558 seconds
# Trip ID: id1931943, Duration: -0.18163610955983506 seconds
# Trip ID: id3626724, Duration: -0.18131056628082454 seconds
# Trip ID: id1569382, Duration: -0.18098502300181402 seconds
# Trip ID: id3629344, Duration: -0.1806594797228035 seconds
# Trip ID: id2473134, Duration: -0.180333936443793 seconds
# Trip ID: id1586668, Duration: -0.18000839316478248 seconds
# Trip ID: id0307250, Duration: -0.17968284988577196 seconds
# Trip ID: id1956067, Duration: -0.17935730660676144 seconds
# Trip ID: id3804261, Duration: -0.17903176332775092 seconds
# Trip ID: id3151509, Duration: -0.17870622004874043 seconds
# Trip ID: id1892188, Duration: -0.1783806767697299 seconds
# Trip ID: id1295221, Duration: -0.17805513349071939 seconds
# Trip ID: id1761582, Duration: -0.17772959021170887 seconds
# Trip ID: id2282234, Duration: -0.17740404693269834 seconds
# Trip ID: id3966560, Duration: -0.17707850365368785 seconds
# Trip ID: id0041355, Duration: -0.17675296037467733 seconds
# Trip ID: id3758275, Duration: -0.1764274170956668 seconds
# Trip ID: id3699092, Duration: -0.1761018738166563 seconds
# Trip ID: id1751469, Duration: -0.17577633053764577 seconds
# Trip ID: id2630502, Duration: -0.17545078725863528 seconds
# Trip ID: id2590899, Duration: -0.17512524397962476 seconds
# Trip ID: id2300944, Duration: -0.17479970070061424 seconds
# Trip ID: id0248613, Duration: -0.17447415742160371 seconds
# Trip ID: id3796832, Duration: -0.1741486141425932 seconds
# Trip ID: id0289045, Duration: -0.1738230708635827 seconds
# Trip ID: id3266451, Duration: -0.17349752758457218 seconds
# Trip ID: id1291293, Duration: -0.17317198430556166 seconds
# Trip ID: id0347608, Duration: -0.17284644102655114 seconds
# Trip ID: id1103508, Duration: -0.17252089774754062 seconds
# Trip ID: id1026009, Duration: -0.17219535446853013 seconds
# Trip ID: id0391450, Duration: -0.1718698111895196 seconds
# Trip ID: id2846326, Duration: -0.17154426791050909 seconds
# Trip ID: id0753916, Duration: -0.17121872463149856 seconds
# Trip ID: id1001339, Duration: -0.17089318135248804 seconds
# Trip ID: id2686766, Duration: -0.17056763807347755 seconds
# Trip ID: id1576081, Duration: -0.17024209479446703 seconds
# Trip ID: id1770931, Duration: -0.1699165515154565 seconds
# Trip ID: id2978433, Duration: -0.169591008236446 seconds
# Trip ID: id0343151, Duration: -0.16926546495743547 seconds
# Trip ID: id2342530, Duration: -0.16893992167842498 seconds
# Trip ID: id0853092, Duration: -0.16861437839941446 seconds
# Trip ID: id0900280, Duration: -0.16828883512040393 seconds
# Trip ID: id3806778, Duration: -0.16796329184139341 seconds
# Trip ID: id1263131, Duration: -0.1676377485623829 seconds
# Trip ID: id1241201, Duration: -0.1673122052833724 seconds
# Trip ID: id1307205, Duration: -0.16698666200436188 seconds
# Trip ID: id3724495, Duration: -0.16666111872535136 seconds
# Trip ID: id3158104, Duration: -0.16633557544634084 seconds
# Trip ID: id0749111, Duration: -0.16601003216733032 seconds
# Trip ID: id3431607, Duration: -0.16568448888831983 seconds
# Trip ID: id2415497, Duration: -0.1653589456093093 seconds
# Trip ID: id0675679, Duration: -0.16503340233029878 seconds
# Trip ID: id0904140, Duration: -0.16470785905128826 seconds
# Trip ID: id2761445, Duration: -0.16438231577227774 seconds
# Trip ID: id1217081, Duration: -0.16405677249326725 seconds
# Trip ID: id0800513, Duration: -0.16373122921425673 seconds
# Trip ID: id2562607, Duration: -0.1634056859352462 seconds
# Trip ID: id3278658, Duration: -0.1630801426562357 seconds
# Trip ID: id3290837, Duration: -0.16275459937722517 seconds
# Trip ID: id3288842, Duration: -0.16242905609821467 seconds
# Trip ID: id1945817, Duration: -0.16210351281920415 seconds
# Trip ID: id0297995, Duration: -0.16177796954019363 seconds
# Trip ID: id1998301, Duration: -0.1614524262611831 seconds
# Trip ID: id3319600, Duration: -0.1611268829821726 seconds
# Trip ID: id0860094, Duration: -0.16080133970316207 seconds
# Trip ID: id1399587, Duration: -0.16047579642415158 seconds
# Trip ID: id0338521, Duration: -0.16015025314514106 seconds
# Trip ID: id1594524, Duration: -0.15982470986613054 seconds
# Trip ID: id3334001, Duration: -0.15949916658712002 seconds
# Trip ID: id3239561, Duration: -0.1591736233081095 seconds
# Trip ID: id0491130, Duration: -0.158848080029099 seconds
# Trip ID: id2122849, Duration: -0.15852253675008848 seconds
# Trip ID: id1537265, Duration: -0.15819699347107796 seconds
# Trip ID: id1957312, Duration: -0.15787145019206744 seconds
# Trip ID: id3082419, Duration: -0.15754590691305692 seconds
# Trip ID: id2105048, Duration: -0.15722036363404643 seconds
# Trip ID: id2872646, Duration: -0.1568948203550359 seconds
# Trip ID: id0808360, Duration: -0.1565692770760254 seconds
# Trip ID: id1830172, Duration: -0.15624373379701487 seconds
# Trip ID: id2634098, Duration: -0.15591819051800435 seconds
# Trip ID: id0127679, Duration: -0.15559264723899385 seconds
# Trip ID: id2529477, Duration: -0.15526710395998333 seconds
# Trip ID: id3918600, Duration: -0.1549415606809728 seconds
# Trip ID: id0333017, Duration: -0.1546160174019623 seconds
# Trip ID: id1093114, Duration: -0.15429047412295177 seconds
# Trip ID: id3346777, Duration: -0.15396493084394128 seconds
# Trip ID: id1869563, Duration: -0.15363938756493076 seconds
# Trip ID: id2880374, Duration: -0.15331384428592024 seconds
# Trip ID: id2438482, Duration: -0.15298830100690972 seconds
# Trip ID: id3379974, Duration: -0.1526627577278992 seconds
# Trip ID: id1299873, Duration: -0.1523372144488887 seconds
# Trip ID: id2880805, Duration: -0.15201167116987818 seconds
# Trip ID: id0556140, Duration: -0.15168612789086766 seconds
# Trip ID: id3772533, Duration: -0.15136058461185714 seconds
# Trip ID: id1860279, Duration: -0.15103504133284662 seconds
# Trip ID: id0160611, Duration: -0.15070949805383613 seconds
# Trip ID: id0478940, Duration: -0.1503839547748256 seconds
# Trip ID: id1309310, Duration: -0.15005841149581509 seconds
# Trip ID: id0137555, Duration: -0.14973286821680457 seconds
# Trip ID: id1250543, Duration: -0.14940732493779404 seconds
# Trip ID: id2599473, Duration: -0.14908178165878355 seconds
# Trip ID: id3708240, Duration: -0.14875623837977303 seconds
# Trip ID: id0398332, Duration: -0.1484306951007625 seconds
# Trip ID: id1251662, Duration: -0.148105151821752 seconds
# Trip ID: id3937910, Duration: -0.14777960854274147 seconds
# Trip ID: id0258203, Duration: -0.14745406526373098 seconds
# Trip ID: id1901629, Duration: -0.14712852198472046 seconds
# Trip ID: id1231110, Duration: -0.14680297870570994 seconds
# Trip ID: id2596080, Duration: -0.14647743542669941 seconds
# Trip ID: id2397984, Duration: -0.1461518921476889 seconds
# Trip ID: id0951710, Duration: -0.1458263488686784 seconds
# Trip ID: id1185778, Duration: -0.14550080558966788 seconds
# Trip ID: id0462545, Duration: -0.14517526231065736 seconds
# Trip ID: id1357824, Duration: -0.14484971903164684 seconds
# Trip ID: id0177531, Duration: -0.14452417575263632 seconds
# Trip ID: id0599646, Duration: -0.14419863247362583 seconds
# Trip ID: id3530376, Duration: -0.1438730891946153 seconds
# Trip ID: id0136212, Duration: -0.14354754591560479 seconds
# Trip ID: id0363672, Duration: -0.14322200263659426 seconds
# Trip ID: id2455615, Duration: -0.14289645935758374 seconds
# Trip ID: id0361358, Duration: -0.14257091607857325 seconds
# Trip ID: id2071080, Duration: -0.14224537279956273 seconds
# Trip ID: id1142413, Duration: -0.1419198295205522 seconds
# Trip ID: id3802334, Duration: -0.1415942862415417 seconds
# Trip ID: id3663990, Duration: -0.14126874296253117 seconds
# Trip ID: id3504416, Duration: -0.14094319968352068 seconds
# Trip ID: id0741421, Duration: -0.14061765640451016 seconds
# Trip ID: id3006727, Duration: -0.14029211312549963 seconds
# Trip ID: id0720646, Duration: -0.13996656984648911 seconds
# Trip ID: id3876842, Duration: -0.1396410265674786 seconds
# Trip ID: id0847393, Duration: -0.1393154832884681 seconds
# Trip ID: id2284656, Duration: -0.13898994000945758 seconds
# Trip ID: id1999123, Duration: -0.13866439673044706 seconds
# Trip ID: id2701527, Duration: -0.13833885345143654 seconds
# Trip ID: id3013818, Duration: -0.13801331017242602 seconds
# Trip ID: id1202307, Duration: -0.13768776689341553 seconds
# Trip ID: id0623014, Duration: -0.137362223614405 seconds
# Trip ID: id1102376, Duration: -0.13703668033539448 seconds
# Trip ID: id1461976, Duration: -0.13671113705638396 seconds
# Trip ID: id1308620, Duration: -0.13638559377737344 seconds
# Trip ID: id3076488, Duration: -0.13606005049836295 seconds
# Trip ID: id0049368, Duration: -0.13573450721935243 seconds
# Trip ID: id1970871, Duration: -0.1354089639403419 seconds
# Trip ID: id0930966, Duration: -0.1350834206613314 seconds
# Trip ID: id0950449, Duration: -0.13475787738232087 seconds
# Trip ID: id0426462, Duration: -0.13443233410331037 seconds
# Trip ID: id0384295, Duration: -0.13410679082429985 seconds
# Trip ID: id0258297, Duration: -0.13378124754528933 seconds
# Trip ID: id1161951, Duration: -0.1334557042662788 seconds
# Trip ID: id3877622, Duration: -0.1331301609872683 seconds
# Trip ID: id1677725, Duration: -0.1328046177082578 seconds
# Trip ID: id0873820, Duration: -0.13247907442924728 seconds
# Trip ID: id3445474, Duration: -0.13215353115023676 seconds
# Trip ID: id0240966, Duration: -0.13182798787122624 seconds
# Trip ID: id1572440, Duration: -0.13150244459221572 seconds
# Trip ID: id2901583, Duration: -0.13117690131320522 seconds
# Trip ID: id1191135, Duration: -0.1308513580341947 seconds
# Trip ID: id0257616, Duration: -0.13052581475518418 seconds
# Trip ID: id2780929, Duration: -0.13020027147617366 seconds
# Trip ID: id2474439, Duration: -0.12987472819716314 seconds
# Trip ID: id1745681, Duration: -0.12954918491815265 seconds
# Trip ID: id3591029, Duration: -0.12922364163914213 seconds
# Trip ID: id2331306, Duration: -0.1288980983601316 seconds
# Trip ID: id3745468, Duration: -0.1285725550811211 seconds
# Trip ID: id2117538, Duration: -0.12824701180211057 seconds
# Trip ID: id0720281, Duration: -0.12792146852310007 seconds
# Trip ID: id0906268, Duration: -0.12759592524408955 seconds
# Trip ID: id2143525, Duration: -0.12727038196507903 seconds
# Trip ID: id3714725, Duration: -0.1269448386860685 seconds
# Trip ID: id3439857, Duration: -0.126619295407058 seconds
# Trip ID: id0612837, Duration: -0.1262937521280475 seconds
# Trip ID: id0023431, Duration: -0.12596820884903698 seconds
# Trip ID: id2023215, Duration: -0.12564266557002646 seconds
# Trip ID: id1231373, Duration: -0.12531712229101594 seconds
# Trip ID: id1659873, Duration: -0.12499157901200543 seconds
# Trip ID: id2501041, Duration: -0.12466603573299491 seconds
# Trip ID: id0299525, Duration: -0.12434049245398439 seconds
# Trip ID: id1684708, Duration: -0.12401494917497388 seconds
# Trip ID: id0147437, Duration: -0.12368940589596336 seconds
# Trip ID: id1143530, Duration: -0.12336386261695285 seconds
# Trip ID: id1192762, Duration: -0.12303831933794233 seconds
# Trip ID: id0616180, Duration: -0.12271277605893181 seconds
# Trip ID: id3862160, Duration: -0.1223872327799213 seconds
# Trip ID: id0763708, Duration: -0.12206168950091079 seconds
# Trip ID: id0375690, Duration: -0.12173614622190028 seconds
# Trip ID: id1101735, Duration: -0.12141060294288976 seconds
# Trip ID: id1215443, Duration: -0.12108505966387924 seconds
# Trip ID: id1141061, Duration: -0.12075951638486873 seconds
# Trip ID: id3061104, Duration: -0.12043397310585821 seconds
# Trip ID: id0307295, Duration: -0.1201084298268477 seconds
# Trip ID: id2998921, Duration: -0.11978288654783718 seconds
# Trip ID: id0120499, Duration: -0.11945734326882666 seconds
# Trip ID: id0470173, Duration: -0.11913179998981616 seconds
# Trip ID: id1272378, Duration: -0.11880625671080564 seconds
# Trip ID: id3530572, Duration: -0.11848071343179513 seconds
# Trip ID: id0990691, Duration: -0.11815517015278461 seconds
# Trip ID: id2306430, Duration: -0.11782962687377409 seconds
# Trip ID: id1308627, Duration: -0.11750408359476358 seconds
# Trip ID: id0221941, Duration: -0.11717854031575306 seconds
# Trip ID: id0509431, Duration: -0.11685299703674255 seconds
# Trip ID: id3860977, Duration: -0.11652745375773203 seconds
# Trip ID: id0804604, Duration: -0.11620191047872151 seconds
# Trip ID: id3940071, Duration: -0.115876367199711 seconds
# Trip ID: id3116140, Duration: -0.11555082392070049 seconds
# Trip ID: id0631336, Duration: -0.11522528064168998 seconds
# Trip ID: id1300284, Duration: -0.11489973736267946 seconds
# Trip ID: id2425143, Duration: -0.11457419408366894 seconds
# Trip ID: id1592166, Duration: -0.11424865080465843 seconds
# Trip ID: id3770771, Duration: -0.11392310752564791 seconds
# Trip ID: id3339691, Duration: -0.1135975642466374 seconds
# Trip ID: id0835585, Duration: -0.11327202096762688 seconds
# Trip ID: id3338018, Duration: -0.11294647768861636 seconds
# Trip ID: id1038442, Duration: -0.11262093440960586 seconds
# Trip ID: id1689214, Duration: -0.11229539113059533 seconds
# Trip ID: id2511055, Duration: -0.11196984785158483 seconds
# Trip ID: id1623875, Duration: -0.11164430457257431 seconds
# Trip ID: id1606255, Duration: -0.11131876129356379 seconds
# Trip ID: id0758162, Duration: -0.11099321801455328 seconds
# Trip ID: id1153360, Duration: -0.11066767473554276 seconds
# Trip ID: id1738661, Duration: -0.11034213145653225 seconds
# Trip ID: id2339923, Duration: -0.11001658817752173 seconds
# Trip ID: id3578056, Duration: -0.10969104489851121 seconds
# Trip ID: id1854020, Duration: -0.1093655016195007 seconds
# Trip ID: id1394430, Duration: -0.10903995834049018 seconds
# Trip ID: id2562592, Duration: -0.10871441506147966 seconds
# Trip ID: id2140916, Duration: -0.10838887178246916 seconds
# Trip ID: id2507611, Duration: -0.10806332850345864 seconds
# Trip ID: id0408403, Duration: -0.10773778522444813 seconds
# Trip ID: id0114914, Duration: -0.10741224194543761 seconds
# Trip ID: id0112108, Duration: -0.10708669866642709 seconds
# Trip ID: id0236715, Duration: -0.10676115538741658 seconds
# Trip ID: id1837274, Duration: -0.10643561210840606 seconds
# Trip ID: id3605384, Duration: -0.10611006882939555 seconds
# Trip ID: id1554571, Duration: -0.10578452555038503 seconds
# Trip ID: id3787075, Duration: -0.10545898227137451 seconds
# Trip ID: id0593444, Duration: -0.105133438992364 seconds
# Trip ID: id0408942, Duration: -0.10480789571335349 seconds
# Trip ID: id2659464, Duration: -0.10448235243434298 seconds
# Trip ID: id3571979, Duration: -0.10415680915533246 seconds
# Trip ID: id1308229, Duration: -0.10383126587632194 seconds
# Trip ID: id2351672, Duration: -0.10350572259731143 seconds
# Trip ID: id3243389, Duration: -0.10318017931830091 seconds
# Trip ID: id1690986, Duration: -0.1028546360392904 seconds
# Trip ID: id1239672, Duration: -0.10252909276027988 seconds
# Trip ID: id2327910, Duration: -0.10220354948126936 seconds
# Trip ID: id1322633, Duration: -0.10187800620225886 seconds
# Trip ID: id0345516, Duration: -0.10155246292324834 seconds
# Trip ID: id2757602, Duration: -0.10122691964423783 seconds
# Trip ID: id1424077, Duration: -0.10090137636522731 seconds
# Trip ID: id3255303, Duration: -0.10057583308621679 seconds
# Trip ID: id1821615, Duration: -0.10025028980720628 seconds
# Trip ID: id2759588, Duration: -0.09992474652819576 seconds
# Trip ID: id1383089, Duration: -0.09959920324918525 seconds
# Trip ID: id1403162, Duration: -0.09927365997017473 seconds
# Trip ID: id1082679, Duration: -0.09894811669116421 seconds
# Trip ID: id0981275, Duration: -0.0986225734121537 seconds
# Trip ID: id2058577, Duration: -0.09829703013314318 seconds
# Trip ID: id1229196, Duration: -0.09797148685413268 seconds
# Trip ID: id2832839, Duration: -0.09764594357512216 seconds
# Trip ID: id1661695, Duration: -0.09732040029611164 seconds
# Trip ID: id3692553, Duration: -0.09699485701710113 seconds
# Trip ID: id3593218, Duration: -0.09666931373809061 seconds
# Trip ID: id1715698, Duration: -0.0963437704590801 seconds
# Trip ID: id3200589, Duration: -0.09601822718006958 seconds
# Trip ID: id0429724, Duration: -0.09569268390105906 seconds
# Trip ID: id1193214, Duration: -0.09536714062204855 seconds
# Trip ID: id1773693, Duration: -0.09504159734303803 seconds
# Trip ID: id1337772, Duration: -0.09471605406402753 seconds
# Trip ID: id0639420, Duration: -0.094390510785017 seconds
# Trip ID: id1005288, Duration: -0.09406496750600649 seconds
# Trip ID: id0432506, Duration: -0.09373942422699598 seconds
# Trip ID: id0448380, Duration: -0.09341388094798546 seconds
# Trip ID: id2365967, Duration: -0.09308833766897495 seconds
# Trip ID: id1835747, Duration: -0.09276279438996443 seconds
# Trip ID: id1168599, Duration: -0.09243725111095391 seconds
# Trip ID: id1985012, Duration: -0.0921117078319434 seconds
# Trip ID: id1691099, Duration: -0.09178616455293288 seconds
# Trip ID: id2087092, Duration: -0.09146062127392238 seconds
# Trip ID: id3296903, Duration: -0.09113507799491186 seconds
# Trip ID: id3993813, Duration: -0.09080953471590134 seconds
# Trip ID: id2573724, Duration: -0.09048399143689083 seconds
# Trip ID: id0198599, Duration: -0.09015844815788031 seconds
# Trip ID: id3057643, Duration: -0.0898329048788698 seconds
# Trip ID: id1573724, Duration: -0.08950736159985928 seconds
# Trip ID: id3627181, Duration: -0.08918181832084876 seconds
# Trip ID: id1853017, Duration: -0.08885627504183825 seconds
# Trip ID: id1945123, Duration: -0.08853073176282773 seconds
# Trip ID: id1232340, Duration: -0.08820518848381723 seconds
# Trip ID: id3085506, Duration: -0.0878796452048067 seconds
# Trip ID: id3300986, Duration: -0.08755410192579619 seconds
# Trip ID: id0771278, Duration: -0.08722855864678568 seconds
# Trip ID: id0053600, Duration: -0.08690301536777516 seconds
# Trip ID: id1581374, Duration: -0.08657747208876464 seconds
# Trip ID: id2246362, Duration: -0.08625192880975413 seconds
# Trip ID: id1881973, Duration: -0.08592638553074361 seconds
# Trip ID: id1538865, Duration: -0.0856008422517331 seconds
# Trip ID: id2240363, Duration: -0.08527529897272258 seconds
# Trip ID: id1868177, Duration: -0.08494975569371206 seconds
# Trip ID: id2837696, Duration: -0.08462421241470156 seconds
# Trip ID: id1926053, Duration: -0.08429866913569103 seconds
# Trip ID: id3496224, Duration: -0.08397312585668053 seconds
# Trip ID: id0287362, Duration: -0.08364758257767001 seconds
# Trip ID: id1793182, Duration: -0.08332203929865949 seconds
# Trip ID: id0029685, Duration: -0.08299649601964898 seconds
# Trip ID: id1741161, Duration: -0.08267095274063846 seconds
# Trip ID: id3792479, Duration: -0.08234540946162795 seconds
# Trip ID: id3971485, Duration: -0.08201986618261743 seconds
# Trip ID: id2634321, Duration: -0.08169432290360691 seconds
# Trip ID: id0011804, Duration: -0.0813687796245964 seconds
# Trip ID: id0582174, Duration: -0.08104323634558588 seconds
# Trip ID: id0880236, Duration: -0.08071769306657538 seconds
# Trip ID: id0263258, Duration: -0.08039214978756486 seconds
# Trip ID: id0856970, Duration: -0.08006660650855434 seconds
# Trip ID: id3057662, Duration: -0.07974106322954383 seconds
# Trip ID: id1144127, Duration: -0.07941551995053331 seconds
# Trip ID: id0983083, Duration: -0.0790899766715228 seconds
# Trip ID: id1194421, Duration: -0.07876443339251228 seconds
# Trip ID: id1839491, Duration: -0.07843889011350176 seconds
# Trip ID: id1477463, Duration: -0.07811334683449125 seconds
# Trip ID: id0599669, Duration: -0.07778780355548073 seconds
# Trip ID: id2994590, Duration: -0.07746226027647023 seconds
# Trip ID: id1022242, Duration: -0.0771367169974597 seconds
# Trip ID: id2817538, Duration: -0.07681117371844919 seconds
# Trip ID: id2100420, Duration: -0.07648563043943868 seconds
# Trip ID: id1744850, Duration: -0.07616008716042816 seconds
# Trip ID: id1562661, Duration: -0.07583454388141765 seconds
# Trip ID: id3507015, Duration: -0.07550900060240713 seconds
# Trip ID: id1596819, Duration: -0.07518345732339661 seconds
# Trip ID: id3091144, Duration: -0.0748579140443861 seconds
# Trip ID: id2651233, Duration: -0.07453237076537558 seconds
# Trip ID: id3594037, Duration: -0.07420682748636508 seconds
# Trip ID: id0376466, Duration: -0.07388128420735456 seconds
# Trip ID: id0414641, Duration: -0.07355574092834403 seconds
# Trip ID: id3436827, Duration: -0.07323019764933353 seconds
# Trip ID: id0310469, Duration: -0.07290465437032301 seconds
# Trip ID: id0841820, Duration: -0.0725791110913125 seconds
# Trip ID: id2182814, Duration: -0.07225356781230198 seconds
# Trip ID: id0344050, Duration: -0.07192802453329146 seconds
# Trip ID: id1221695, Duration: -0.07160248125428095 seconds
# Trip ID: id0557335, Duration: -0.07127693797527043 seconds
# Trip ID: id2977581, Duration: -0.07095139469625993 seconds
# Trip ID: id3650587, Duration: -0.0706258514172494 seconds
# Trip ID: id3734269, Duration: -0.07030030813823888 seconds
# Trip ID: id1456913, Duration: -0.06997476485922838 seconds
# Trip ID: id2457580, Duration: -0.06964922158021786 seconds
# Trip ID: id0065810, Duration: -0.06932367830120735 seconds
# Trip ID: id1684552, Duration: -0.06899813502219683 seconds
# Trip ID: id0637913, Duration: -0.06867259174318631 seconds
# Trip ID: id2623546, Duration: -0.0683470484641758 seconds
# Trip ID: id0966229, Duration: -0.06802150518516528 seconds
# Trip ID: id0951681, Duration: -0.06769596190615478 seconds
# Trip ID: id0279794, Duration: -0.06737041862714425 seconds
# Trip ID: id0344846, Duration: -0.06704487534813373 seconds
# Trip ID: id0114523, Duration: -0.06671933206912323 seconds
# Trip ID: id2710133, Duration: -0.0663937887901127 seconds
# Trip ID: id1884419, Duration: -0.06606824551110219 seconds
# Trip ID: id2180482, Duration: -0.06574270223209168 seconds
# Trip ID: id2135846, Duration: -0.06541715895308116 seconds
# Trip ID: id2571288, Duration: -0.06509161567407065 seconds
# Trip ID: id3377606, Duration: -0.06476607239506013 seconds
# Trip ID: id2668448, Duration: -0.06444052911604961 seconds
# Trip ID: id3356675, Duration: -0.0641149858370391 seconds
# Trip ID: id1269552, Duration: -0.06378944255802858 seconds
# Trip ID: id2267138, Duration: -0.06346389927901808 seconds
# Trip ID: id2558773, Duration: -0.06313835600000756 seconds
# Trip ID: id3463550, Duration: -0.06281281272099704 seconds
# Trip ID: id1023008, Duration: -0.06248726944198653 seconds
# Trip ID: id2765197, Duration: -0.062161726162976015 seconds
# Trip ID: id2794573, Duration: -0.061836182883965495 seconds
# Trip ID: id1688695, Duration: -0.06151063960495498 seconds
# Trip ID: id1690946, Duration: -0.06118509632594447 seconds
# Trip ID: id3175994, Duration: -0.060859553046933954 seconds
# Trip ID: id3068325, Duration: -0.06053400976792343 seconds
# Trip ID: id0883196, Duration: -0.06020846648891292 seconds
# Trip ID: id2862050, Duration: -0.059882923209902406 seconds
# Trip ID: id1939692, Duration: -0.05955737993089189 seconds
# Trip ID: id1301473, Duration: -0.05923183665188138 seconds
# Trip ID: id3945222, Duration: -0.05890629337287086 seconds
# Trip ID: id3302171, Duration: -0.058580750093860344 seconds
# Trip ID: id3622690, Duration: -0.05825520681484983 seconds
# Trip ID: id1508580, Duration: -0.05792966353583932 seconds
# Trip ID: id1560595, Duration: -0.0576041202568288 seconds
# Trip ID: id0574872, Duration: -0.05727857697781828 seconds
# Trip ID: id0925611, Duration: -0.05695303369880777 seconds
# Trip ID: id0558047, Duration: -0.056627490419797255 seconds
# Trip ID: id2942835, Duration: -0.05630194714078674 seconds
# Trip ID: id3329308, Duration: -0.05597640386177623 seconds
# Trip ID: id0133766, Duration: -0.05565086058276571 seconds
# Trip ID: id1894685, Duration: -0.05532531730375519 seconds
# Trip ID: id3202721, Duration: -0.05499977402474468 seconds
# Trip ID: id0141408, Duration: -0.054674230745734166 seconds
# Trip ID: id2800257, Duration: -0.05434868746672365 seconds
# Trip ID: id1226337, Duration: -0.05402314418771313 seconds
# Trip ID: id1468552, Duration: -0.05369760090870262 seconds
# Trip ID: id1525199, Duration: -0.053372057629692105 seconds
# Trip ID: id0280854, Duration: -0.05304651435068159 seconds
# Trip ID: id3148818, Duration: -0.05272097107167108 seconds
# Trip ID: id2109478, Duration: -0.05239542779266056 seconds
# Trip ID: id2944393, Duration: -0.05206988451365004 seconds
# Trip ID: id0824978, Duration: -0.05174434123463953 seconds
# Trip ID: id2775174, Duration: -0.051418797955629016 seconds
# Trip ID: id2765444, Duration: -0.0510932546766185 seconds
# Trip ID: id3458821, Duration: -0.05076771139760798 seconds
# Trip ID: id3503167, Duration: -0.05044216811859747 seconds
# Trip ID: id3932810, Duration: -0.050116624839586954 seconds
# Trip ID: id0771287, Duration: -0.04979108156057644 seconds
# Trip ID: id3751354, Duration: -0.04946553828156592 seconds
# Trip ID: id2294003, Duration: -0.049139995002555406 seconds
# Trip ID: id1633622, Duration: -0.04881445172354489 seconds
# Trip ID: id2625381, Duration: -0.04848890844453438 seconds
# Trip ID: id2352711, Duration: -0.048163365165523865 seconds
# Trip ID: id1708629, Duration: -0.047837821886513344 seconds
# Trip ID: id1123626, Duration: -0.04751227860750283 seconds
# Trip ID: id1248428, Duration: -0.04718673532849232 seconds
# Trip ID: id2770543, Duration: -0.046861192049481804 seconds
# Trip ID: id2227372, Duration: -0.04653564877047129 seconds
# Trip ID: id0806920, Duration: -0.04621010549146077 seconds
# Trip ID: id1972355, Duration: -0.045884562212450256 seconds
# Trip ID: id0260447, Duration: -0.04555901893343974 seconds
# Trip ID: id3699254, Duration: -0.04523347565442923 seconds
# Trip ID: id3943657, Duration: -0.044907932375418715 seconds
# Trip ID: id3198500, Duration: -0.044582389096408194 seconds
# Trip ID: id1505587, Duration: -0.04425684581739768 seconds
# Trip ID: id2127962, Duration: -0.04393130253838717 seconds
# Trip ID: id1692534, Duration: -0.04360575925937665 seconds
# Trip ID: id0428061, Duration: -0.04328021598036614 seconds
# Trip ID: id3426502, Duration: -0.04295467270135562 seconds
# Trip ID: id1527119, Duration: -0.042629129422345105 seconds
# Trip ID: id3466402, Duration: -0.04230358614333459 seconds
# Trip ID: id3857787, Duration: -0.04197804286432408 seconds
# Trip ID: id0552738, Duration: -0.041652499585313564 seconds
# Trip ID: id2511353, Duration: -0.04132695630630304 seconds
# Trip ID: id1975239, Duration: -0.04100141302729253 seconds
# Trip ID: id3100604, Duration: -0.040675869748282016 seconds
# ...
# Trip ID: id0541451, Duration: 0.7429068028300279 seconds
# Trip ID: id2881874, Duration: 0.7432323461090383 seconds
# Trip ID: id0240216, Duration: 0.7442089759460698 seconds
# Trip ID: id3766018, Duration: 0.7451856057831014 seconds
# Trip ID: id0658283, Duration: 0.7455111490621119 seconds
# Trip ID: id2165009, Duration: 0.7458366923411225 seconds
# Trip ID: id0932904, Duration: 0.746813322178154 seconds
# Trip ID: id0391005, Duration: 0.7494176684102382 seconds
# Trip ID: id2148056, Duration: 0.7497432116892486 seconds
# Trip ID: id0885705, Duration: 0.7503942982472697 seconds
# Trip ID: id0171221, Duration: 0.7507198415262801 seconds
# Trip ID: id2517400, Duration: 0.7526731012003433 seconds
# Trip ID: id2144875, Duration: 0.7533241877583643 seconds
# Trip ID: id1909659, Duration: 0.7536497310373748 seconds
# Trip ID: id2251320, Duration: 0.7539752743163853 seconds
# Trip ID: id1709640, Duration: 0.7543008175953958 seconds
# Trip ID: id1716831, Duration: 0.7552774474324274 seconds
# Trip ID: id3741190, Duration: 0.7562540772694589 seconds
# Trip ID: id3595415, Duration: 0.7565796205484695 seconds
# Trip ID: id2065746, Duration: 0.75690516382748 seconds
# Trip ID: id0426003, Duration: 0.7585328802225325 seconds
# Trip ID: id2633795, Duration: 0.7591839667805536 seconds
# Trip ID: id1573080, Duration: 0.7604861398965956 seconds
# Trip ID: id1557835, Duration: 0.7608116831756061 seconds
# Trip ID: id3859162, Duration: 0.7614627697336271 seconds
# Trip ID: id2452759, Duration: 0.7617883130126377 seconds
# Trip ID: id3266139, Duration: 0.7621138562916482 seconds
# Trip ID: id3345286, Duration: 0.7630904861286798 seconds
# Trip ID: id1135965, Duration: 0.7634160294076903 seconds
# Trip ID: id2951712, Duration: 0.7637415726867007 seconds
# Trip ID: id0746345, Duration: 0.7643926592447218 seconds
# Trip ID: id1301983, Duration: 0.7663459189187849 seconds
# Trip ID: id2378488, Duration: 0.7666714621977955 seconds
# Trip ID: id3653564, Duration: 0.7673225487558164 seconds
# Trip ID: id0876589, Duration: 0.768299178592848 seconds
# Trip ID: id3190766, Duration: 0.7686247218718585 seconds
# Trip ID: id2667235, Duration: 0.7689502651508691 seconds
# Trip ID: id2760027, Duration: 0.7696013517088901 seconds
# Trip ID: id2339567, Duration: 0.770252438266911 seconds
# Trip ID: id3409038, Duration: 0.7705779815459216 seconds
# Trip ID: id2802798, Duration: 0.7712290681039426 seconds
# Trip ID: id0778598, Duration: 0.7722056979409742 seconds
# Trip ID: id2252169, Duration: 0.7731823277780058 seconds
# Trip ID: id1882379, Duration: 0.7744845008940477 seconds
# Trip ID: id2276648, Duration: 0.7764377605681109 seconds
# Trip ID: id2299852, Duration: 0.7774143904051424 seconds
# Trip ID: id2200019, Duration: 0.7787165635211845 seconds
# Trip ID: id3041739, Duration: 0.779042106800195 seconds
# Trip ID: id2693209, Duration: 0.7793676500792055 seconds
# Trip ID: id3476990, Duration: 0.7800187366372265 seconds
# Trip ID: id1620362, Duration: 0.780344279916237 seconds
# Trip ID: id0699291, Duration: 0.7819719963112897 seconds
# Trip ID: id1233230, Duration: 0.7822975395903001 seconds
# Trip ID: id3296971, Duration: 0.7829486261483212 seconds
# Trip ID: id0151255, Duration: 0.7835997127063422 seconds
# Trip ID: id1404553, Duration: 0.7842507992643633 seconds
# Trip ID: id3872476, Duration: 0.7852274291013948 seconds
# Trip ID: id2283177, Duration: 0.7862040589384264 seconds
# Trip ID: id3952011, Duration: 0.7888084051705104 seconds
# Trip ID: id2617758, Duration: 0.790436121565563 seconds
# Trip ID: id3390491, Duration: 0.7914127514025946 seconds
# Trip ID: id1870038, Duration: 0.7920638379606156 seconds
# Trip ID: id3188875, Duration: 0.7927149245186367 seconds
# Trip ID: id3054510, Duration: 0.7943426409136892 seconds
# Trip ID: id0509898, Duration: 0.7956448140297313 seconds
# Trip ID: id1670945, Duration: 0.7969469871457733 seconds
# Trip ID: id2072188, Duration: 0.800527963214889 seconds
# Trip ID: id3613051, Duration: 0.80117904977291 seconds
# Trip ID: id2229765, Duration: 0.8028067661679626 seconds
# Trip ID: id0147632, Duration: 0.8050855691210362 seconds
# Trip ID: id2060168, Duration: 0.8057366556790573 seconds
# Trip ID: id3840229, Duration: 0.8067132855160888 seconds
# Trip ID: id0714866, Duration: 0.809317631748173 seconds
# Trip ID: id2280531, Duration: 0.8102942615852045 seconds
# Trip ID: id0365591, Duration: 0.8109453481432255 seconds
# Trip ID: id2719465, Duration: 0.811270891422236 seconds
# Trip ID: id2093042, Duration: 0.8115964347012465 seconds
# Trip ID: id2342196, Duration: 0.8145263242123412 seconds
# Trip ID: id3294046, Duration: 0.8151774107703622 seconds
# Trip ID: id3193370, Duration: 0.8155029540493727 seconds
# Trip ID: id3345389, Duration: 0.8171306704444252 seconds
# Trip ID: id3299474, Duration: 0.8174562137234358 seconds
# Trip ID: id1513001, Duration: 0.8177817570024463 seconds
# Trip ID: id3673813, Duration: 0.8181073002814568 seconds
# Trip ID: id1175724, Duration: 0.8210371897925515 seconds
# Trip ID: id1241998, Duration: 0.8229904494666145 seconds
# Trip ID: id3676949, Duration: 0.8246181658616671 seconds
# Trip ID: id2852164, Duration: 0.8268969688147407 seconds
# Trip ID: id2225888, Duration: 0.8301524016048458 seconds
# Trip ID: id1691476, Duration: 0.8308034881628669 seconds
# Trip ID: id1226836, Duration: 0.8311290314418774 seconds
# Trip ID: id1954030, Duration: 0.832105661278909 seconds
# Trip ID: id3221654, Duration: 0.83275674783693 seconds
# Trip ID: id2068860, Duration: 0.8330822911159405 seconds
# Trip ID: id3565003, Duration: 0.8340589209529721 seconds
# Trip ID: id1342608, Duration: 0.8350355507900036 seconds
# Trip ID: id3029360, Duration: 0.8356866373480246 seconds
# Trip ID: id0259706, Duration: 0.8402442432541718 seconds
# Trip ID: id0222018, Duration: 0.8425230462072454 seconds
# Trip ID: id1252578, Duration: 0.8431741327652664 seconds
# Trip ID: id0732070, Duration: 0.843499676044277 seconds
# Trip ID: id0782784, Duration: 0.8454529357183401 seconds
# Trip ID: id2561691, Duration: 0.8457784789973506 seconds
# Trip ID: id1547623, Duration: 0.8464295655553716 seconds
# Trip ID: id3838456, Duration: 0.8487083685084452 seconds
# Trip ID: id3780457, Duration: 0.8490339117874557 seconds
# Trip ID: id0834355, Duration: 0.8493594550664663 seconds
# Trip ID: id0785416, Duration: 0.8496849983454767 seconds
# Trip ID: id2194328, Duration: 0.8519638012985504 seconds
# Trip ID: id2199979, Duration: 0.856195863925687 seconds
# Trip ID: id2633086, Duration: 0.8581491235997502 seconds
# Trip ID: id3890157, Duration: 0.8597768399948027 seconds
# Trip ID: id2468264, Duration: 0.8607534698318343 seconds
# Trip ID: id1296979, Duration: 0.8614045563898554 seconds
# Trip ID: id0685901, Duration: 0.8617300996688658 seconds
# Trip ID: id1193454, Duration: 0.8646599891799605 seconds
# Trip ID: id0017584, Duration: 0.8653110757379815 seconds
# Trip ID: id0579483, Duration: 0.8679154219700657 seconds
# Trip ID: id2805122, Duration: 0.8688920518070972 seconds
# Trip ID: id2531025, Duration: 0.8692175950861076 seconds
# Trip ID: id2721008, Duration: 0.8718219413181918 seconds
# Trip ID: id2005368, Duration: 0.8754029173873075 seconds
# Trip ID: id2128334, Duration: 0.8780072636193916 seconds
# Trip ID: id2113940, Duration: 0.8783328068984021 seconds
# Trip ID: id3316989, Duration: 0.8799605232934546 seconds
# Trip ID: id0971933, Duration: 0.8802860665724652 seconds
# Trip ID: id2961282, Duration: 0.8819137829675178 seconds
# Trip ID: id3514411, Duration: 0.8822393262465282 seconds
# Trip ID: id2464755, Duration: 0.8828904128045493 seconds
# Trip ID: id1577616, Duration: 0.8835414993625703 seconds
# Trip ID: id3176551, Duration: 0.8854947590366334 seconds
# Trip ID: id1319634, Duration: 0.8920056246168437 seconds
# Trip ID: id3813537, Duration: 0.8929822544538752 seconds
# Trip ID: id2112664, Duration: 0.8936333410118963 seconds
# Trip ID: id2391777, Duration: 0.8942844275699173 seconds
# Trip ID: id1401650, Duration: 0.8962376872439805 seconds
# Trip ID: id3091223, Duration: 0.897214317081012 seconds
# Trip ID: id3837691, Duration: 0.898516490197054 seconds
# Trip ID: id3187699, Duration: 0.8998186633130961 seconds
# Trip ID: id2800261, Duration: 0.9007952931501276 seconds
# Trip ID: id1788284, Duration: 0.9024230095451802 seconds
# Trip ID: id1668368, Duration: 0.9030740961032012 seconds
# Trip ID: id0336324, Duration: 0.9043762692192433 seconds
# Trip ID: id3765851, Duration: 0.9047018124982538 seconds
# Trip ID: id1285079, Duration: 0.9053528990562748 seconds
# Trip ID: id1502575, Duration: 0.9056784423352854 seconds
# Trip ID: id1734732, Duration: 0.9060039856142958 seconds
# Trip ID: id0076678, Duration: 0.9063295288933064 seconds
# Trip ID: id2166489, Duration: 0.9069806154513275 seconds
# Trip ID: id1395091, Duration: 0.90860833184638 seconds
# Trip ID: id3862229, Duration: 0.909259418404401 seconds
# Trip ID: id0594311, Duration: 0.9102360482414326 seconds
# Trip ID: id2069468, Duration: 0.9144681108685693 seconds
# Trip ID: id3108396, Duration: 0.918700173495706 seconds
# Trip ID: id1697137, Duration: 0.919351260053727 seconds
# Trip ID: id2517644, Duration: 0.9196768033327375 seconds
# Trip ID: id3763011, Duration: 0.9209789764487796 seconds
# Trip ID: id2596383, Duration: 0.9229322361228427 seconds
# Trip ID: id1678771, Duration: 0.9235833226808637 seconds
# Trip ID: id1565814, Duration: 0.9239088659598742 seconds
# Trip ID: id0197610, Duration: 0.9242344092388847 seconds
# Trip ID: id0195754, Duration: 0.9248854957969057 seconds
# Trip ID: id1746851, Duration: 0.9261876689129478 seconds
# Trip ID: id0144612, Duration: 0.929443101703053 seconds
# Trip ID: id0763170, Duration: 0.9304197315400845 seconds
# Trip ID: id2881104, Duration: 0.9307452748190951 seconds
# Trip ID: id2578278, Duration: 0.932047447935137 seconds
# Trip ID: id1299501, Duration: 0.9323729912141476 seconds
# Trip ID: id2459069, Duration: 0.9340007076092002 seconds
# Trip ID: id0876073, Duration: 0.9356284240042527 seconds
# Trip ID: id1239377, Duration: 0.9408371164684209 seconds
# Trip ID: id2899321, Duration: 0.9437670059795157 seconds
# Trip ID: id1145006, Duration: 0.9450691790955577 seconds
# Trip ID: id0567326, Duration: 0.9486501551646733 seconds
# Trip ID: id2541475, Duration: 0.9571142804189468 seconds
# Trip ID: id2078843, Duration: 0.9587419968139993 seconds
# Trip ID: id1134967, Duration: 0.9600441699300414 seconds
# Trip ID: id3364378, Duration: 0.962974059441136 seconds
# Trip ID: id2056131, Duration: 0.9701360115793674 seconds
# Trip ID: id3688044, Duration: 0.9759957906015566 seconds
# Trip ID: id2711541, Duration: 0.9769724204385881 seconds
# Trip ID: id1924642, Duration: 0.9782745935546302 seconds
# Trip ID: id3131934, Duration: 0.9786001368336408 seconds
# Trip ID: id0906708, Duration: 0.9792512233916618 seconds
# Trip ID: id3175097, Duration: 0.9795767666706723 seconds
# Trip ID: id1183853, Duration: 0.9821811129027564 seconds
# Trip ID: id0544665, Duration: 0.9903196948780193 seconds
# Trip ID: id0410687, Duration: 0.9919474112730718 seconds
# Trip ID: id0040020, Duration: 1.0004115365273452 seconds
# Trip ID: id2720434, Duration: 1.0013881663643769 seconds
# Trip ID: id2423388, Duration: 1.0023647962014084 seconds
# Trip ID: id3706747, Duration: 1.0043180558754714 seconds
# Trip ID: id2510809, Duration: 1.0108289214556818 seconds
# Trip ID: id3386958, Duration: 1.0209207631050077 seconds
# Trip ID: id0770212, Duration: 1.0238506526161024 seconds
# Trip ID: id0046828, Duration: 1.024827282453134 seconds
# Trip ID: id3287666, Duration: 1.0271060854062075 seconds
# Trip ID: id3494823, Duration: 1.0290593450802705 seconds
# Trip ID: id0990606, Duration: 1.0297104316382917 seconds
# Trip ID: id1698333, Duration: 1.0310126047543338 seconds
# Trip ID: id0196115, Duration: 1.0319892345913653 seconds
# Trip ID: id1736691, Duration: 1.0323147778703758 seconds
# Trip ID: id3599570, Duration: 1.0352446673814704 seconds
# Trip ID: id3983261, Duration: 1.0365468404975124 seconds
# Trip ID: id0381992, Duration: 1.036872383776523 seconds
# Trip ID: id2100452, Duration: 1.0485919418209015 seconds
# Trip ID: id2297072, Duration: 1.049568571657933 seconds
# Trip ID: id1097268, Duration: 1.050219658215954 seconds
# Trip ID: id3447722, Duration: 1.0524984611690276 seconds
# Trip ID: id3805564, Duration: 1.0528240044480381 seconds
# Trip ID: id3977233, Duration: 1.0625903028183536 seconds
# Trip ID: id1780736, Duration: 1.0635669326553852 seconds
# Trip ID: id0102454, Duration: 1.0655201923294482 seconds
# Trip ID: id1907876, Duration: 1.0694267116775744 seconds
# Trip ID: id2524695, Duration: 1.069752254956585 seconds
# Trip ID: id2254896, Duration: 1.0720310579096586 seconds
# Trip ID: id3328638, Duration: 1.0723566011886692 seconds
# Trip ID: id1133983, Duration: 1.0765886638158058 seconds
# Trip ID: id3548834, Duration: 1.0782163802108584 seconds
# Trip ID: id3634301, Duration: 1.0909125680922684 seconds
# Trip ID: id1307442, Duration: 1.0918891979293 seconds
# Trip ID: id2163330, Duration: 1.0993766933465419 seconds
# Trip ID: id1304382, Duration: 1.1010044097415945 seconds
# Trip ID: id0257474, Duration: 1.1036087559736785 seconds
# Trip ID: id0624014, Duration: 1.1065386454847732 seconds
# Trip ID: id1625923, Duration: 1.1075152753218047 seconds
# Trip ID: id1836482, Duration: 1.116630487134099 seconds
# Trip ID: id2776619, Duration: 1.124117982551341 seconds
# Trip ID: id1791249, Duration: 1.1263967855044146 seconds
# Trip ID: id2309080, Duration: 1.1267223287834252 seconds
# Trip ID: id1341302, Duration: 1.1283500451784776 seconds
# Trip ID: id0351116, Duration: 1.1319310212475933 seconds
# Trip ID: id2141561, Duration: 1.134860910758688 seconds
# Trip ID: id3247080, Duration: 1.1384418868278037 seconds
# Trip ID: id2555587, Duration: 1.1400696032228563 seconds
# Trip ID: id0535769, Duration: 1.1407206897808773 seconds
# Trip ID: id0060098, Duration: 1.1449527524080139 seconds
# Trip ID: id2540536, Duration: 1.14885927175614 seconds
# Trip ID: id2651961, Duration: 1.1517891612672349 seconds
# Trip ID: id1084960, Duration: 1.1524402478252558 seconds
# Trip ID: id0518336, Duration: 1.1648108924276555 seconds
# Trip ID: id1399634, Duration: 1.188575551795423 seconds
# Trip ID: id2494479, Duration: 1.19931848000277 seconds
# Trip ID: id1465827, Duration: 1.21201466788418 seconds
# Trip ID: id3668868, Duration: 1.2155956439532958 seconds
# Trip ID: id1981693, Duration: 1.2188510767434009 seconds
# Trip ID: id2427748, Duration: 1.2338260675778845 seconds
# Trip ID: id2262852, Duration: 1.246847798738305 seconds
# Trip ID: id0783254, Duration: 1.2514054046444525 seconds
# Trip ID: id3984281, Duration: 1.2533586643185155 seconds
# Trip ID: id1019404, Duration: 1.2614972462937784 seconds
# Trip ID: id1539263, Duration: 1.2722401745011254 seconds
# Trip ID: id0834441, Duration: 1.2823320161504512 seconds
# Trip ID: id1147522, Duration: 1.2953537473108718 seconds
# Trip ID: id2550439, Duration: 1.3051200456811873 seconds
# Trip ID: id1009342, Duration: 1.334093397513123 seconds
# Trip ID: id1622983, Duration: 1.354277080811775 seconds
# Trip ID: id0243519, Duration: 1.3549281673697962 seconds
# Trip ID: id1480601, Duration: 1.3679498985302168 seconds
# Trip ID: id1395535, Duration: 1.3806460864116268 seconds
# Trip ID: id2016641, Duration: 1.3933422742930368 seconds
# Trip ID: id2180879, Duration: 1.4047362890584048 seconds
# Trip ID: id3166949, Duration: 1.4167813903817938 seconds
# Trip ID: id2715742, Duration: 1.4190601933348674 seconds
# Trip ID: id0321011, Duration: 1.4255710589150778 seconds
# Trip ID: id2253572, Duration: 1.4398949631915405 seconds
# Trip ID: id3978400, Duration: 1.448359088445814 seconds
# Trip ID: id0706029, Duration: 1.4600786464901925 seconds
# Trip ID: id2455471, Duration: 1.4613808196062346 seconds
# Trip ID: id0598906, Duration: 1.5072824219467171 seconds
# Trip ID: id2599873, Duration: 1.5124911144108855 seconds
# Trip ID: id3806679, Duration: 1.514118830805938 seconds
# Trip ID: id1452618, Duration: 1.5714144479117886 seconds
# Trip ID: id0998434, Duration: 1.602015516138777 seconds
# Trip ID: id3300797, Duration: 1.6072242086029453 seconds
# Trip ID: id2806945, Duration: 1.655730157175512 seconds
# Trip ID: id1424187, Duration: 1.7533931408786665 seconds
# Trip ID: id3799848, Duration: 1.8836104524828725 seconds
# Trip ID: id0413474, Duration: 1.92625662203325 seconds
# Trip ID: id2456201, Duration: 2.3943878572503707 seconds
# Trip ID: new_trp_id, Duration: 500 seconds

# %%
import random

random_phone_numbers = [f"{random.randint(100, 999)}-{random.randint(100, 999)}-{random.randint(1000, 9999)}" for _ in range(len(df))]

# Adding the 'phone_number' column to the DataFrame
df['phone_number'] = random_phone_numbers


print(df)
# Out:
#                 id  vendor_id     pickup_datetime    dropoff_datetime  \
# 209174   id2104500          1 2016-03-09 20:09:32 2016-03-09 20:33:18
# 1296156  id1063788          1 2016-05-26 08:38:50 2016-05-26 08:51:19
# 136770   id1376921          0 2016-06-12 10:36:15 2016-06-12 10:50:21
# 219673   id1418169          1 2016-06-26 02:13:21 2016-06-26 02:16:28
# 218117   id2470055          1 2016-02-17 11:33:38 2016-02-17 11:39:45
# ...            ...        ...                 ...                 ...
# 1457328  id0584362          0 2016-06-23 11:39:08 2016-06-23 12:12:10
# 471121   id3134223          0 2016-04-16 01:34:03 2016-04-16 01:37:55
# 527507   id3428610          1 2016-02-04 21:37:44 2016-02-04 21:43:00
# 260392   id0320852          0 2016-02-28 20:20:10 2016-02-28 20:24:17
# 1151751  id3620140          0 2016-02-09 22:51:56 2016-02-09 23:06:14
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 209174                 5              0.50             0.76
# 1296156                1              0.50             0.76
# 136770                 1              0.50             0.76
# 219673                 1              0.50             0.76
# 218117                 1              0.50             0.76
# ...                  ...               ...              ...
# 1457328                1              0.50             0.76
# 471121                 1              0.50             0.76
# 527507                 5              0.50             0.76
# 260392                 1              0.50             0.76
# 1151751                2              0.50             0.76
#
#          dropoff_longitude  dropoff_latitude  trip_duration  month    weekday  \
# 209174                0.62              0.63           0.16      3  Wednesday
# 1296156               0.61              0.64          -0.06      5   Thursday
# 136770                0.61              0.63          -0.03      6     Sunday
# 219673                0.62              0.64          -0.25      6     Sunday
# 218117                0.61              0.64          -0.19      2  Wednesday
# ...                    ...               ...            ...    ...        ...
# 1457328               0.62              0.64           0.34      6   Thursday
# 471121                0.61              0.64          -0.23      4   Saturday
# 527507                0.61              0.64          -0.20      2   Thursday
# 260392                0.62              0.64          -0.23      2     Sunday
# 1151751               0.61              0.63          -0.03      2    Tuesday
#
#          weekday_num  pickup_hour  store_and_fwd_flag_Y  phone_number
# 209174             2           20                 False  828-892-6076
# 1296156            3            8                 False  753-425-9177
# 136770             6           10                 False  406-453-7371
# 219673             6            2                 False  502-877-6956
# 218117             2           11                 False  255-170-3648
# ...              ...          ...                   ...           ...
# 1457328            3           11                 False  950-754-4566
# 471121             5            1                 False  980-150-1905
# 527507             3           21                 False  491-360-1355
# 260392             6           20                 False  629-979-9599
# 1151751            1           22                 False  421-466-9522
#
# [95944 rows x 16 columns]

# %%
# Check the random phone numbers for the first 3 rows of data
for i in range(3):
    row = df.iloc[i]
    phone_number = row['phone_number']
    print(f"Row {i + 1} - Phone Number: {phone_number}")
# Out:
# Row 1 - Phone Number: 828-892-6076
# Row 2 - Phone Number: 753-425-9177
# Row 3 - Phone Number: 406-453-7371

# %%
df.head()
# Out:
#                 id  vendor_id     pickup_datetime    dropoff_datetime  \
# 209174   id2104500          1 2016-03-09 20:09:32 2016-03-09 20:33:18
# 1296156  id1063788          1 2016-05-26 08:38:50 2016-05-26 08:51:19
# 136770   id1376921          0 2016-06-12 10:36:15 2016-06-12 10:50:21
# 219673   id1418169          1 2016-06-26 02:13:21 2016-06-26 02:16:28
# 218117   id2470055          1 2016-02-17 11:33:38 2016-02-17 11:39:45
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 209174                 5              0.50             0.76
# 1296156                1              0.50             0.76
# 136770                 1              0.50             0.76
# 219673                 1              0.50             0.76
# 218117                 1              0.50             0.76
#
#          dropoff_longitude  dropoff_latitude  trip_duration  month    weekday  \
# 209174                0.62              0.63           0.16      3  Wednesday
# 1296156               0.61              0.64          -0.06      5   Thursday
# 136770                0.61              0.63          -0.03      6     Sunday
# 219673                0.62              0.64          -0.25      6     Sunday
# 218117                0.61              0.64          -0.19      2  Wednesday
#
#          weekday_num  pickup_hour  store_and_fwd_flag_Y  phone_number
# 209174             2           20                 False  828-892-6076
# 1296156            3            8                 False  753-425-9177
# 136770             6           10                 False  406-453-7371
# 219673             6            2                 False  502-877-6956
# 218117             2           11                 False  255-170-3648
